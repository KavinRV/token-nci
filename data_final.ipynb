# %%
import pandas as pd

def read_jsonl(file_path, nrows=None):
    return pd.read_json(file_path, lines=True, nrows=nrows)

train_data = read_jsonl("phase_2_input_data/training_data/train.features")
train_solution = read_jsonl("phase_2_input_data/training_data/train.labels")

# %%
train_data = train_data.merge(train_solution, on="indoml_id", how="left")

# %%
train_data.head()
# Out:
#    indoml_id             description      retailer  price  supergroup  \
# 0          0                1 adblue  organicorner  25.35  automotive
# 1          1           1 car mat set   greenharbor   4.99  automotive
# 2          2       1 cp rmx scrnwash      naturify   3.85  automotive
# 3          3                1 diesel        ecogro   4.41  automotive
# 4          4  1 unstoppable refrsher   greenharbor   3.00  automotive
#
#                              group      module        brand
# 0  automotive detail unknown total  automotive  receipt all
# 1  automotive detail unknown total  automotive  receipt all
# 2  automotive detail unknown total  automotive  receipt all
# 3  automotive detail unknown total  automotive  receipt all
# 4  automotive detail unknown total  automotive  receipt all

# %%
train_data["int_price"] = train_data["price"].apply(lambda x: float(x))
# convert nan to 0
train_data["int_price"] = train_data["int_price"].fillna(0)
train_data["int_price"] = train_data["int_price"].astype(int)
train_data["int_price"] = train_data["int_price"].astype(str)

# create a query, which has the retailer, price, and the description of the product
train_data["query"] = "retailer: " + train_data["retailer"] + " " + "price: " + train_data["int_price"] + " " + "description: " + train_data["description"]

# %%
# sample query
train_data['query'].sample(3).values
# Out:
# array(['retailer: orchidora price: 1 description: family chicken fie',
#        'retailer: savormart price: 0 description: x 175 g haribo tangfastics',
#        'retailer: orchidora price: 2 description: j 20 applemango'],
#       dtype=object)

# %%
# we process the brand seperately and group the module, group, and supergroup into one single target format
 
train_data["mod_grp_sg"] = train_data["module"] + "<|>" + train_data["group"] + "<|>" + train_data["supergroup"]
mod_grp_sg = train_data["mod_grp_sg"].unique()

mod_out_dct = {}
for i in mod_grp_sg:
    mgs_lst = i.split("<|>")
    mod_out_dct[mgs_lst[0]] = {"module": mgs_lst[0], "group": mgs_lst[1], "supergroup": mgs_lst[2]}

import pickle
with open("mod_out_dct.pkl", "wb") as f:
    pickle.dump(mod_out_dct, f)

# every module is uniquley determined by a group-supergroup pair
len(mod_out_dct)
# Out:
# 449

# %%
brand = train_data["brand"].unique()

br_out_dct = {}
for i in brand:
    br_out_dct[i] = {"brand": i}

with open("br_out_dct.pkl", "wb") as f:
    pickle.dump(br_out_dct, f)

# %%
br_out_dct
# Out:
# {'receipt all': {'brand': 'receipt all'},
#  'huggies': {'brand': 'huggies'},
#  'nourify': {'brand': 'nourify'},
#  'pure baby': {'brand': 'pure baby'},
#  'verdemart': {'brand': 'verdemart'},
#  'avent': {'brand': 'avent'},
#  'crispcorner': {'brand': 'crispcorner'},
#  'crispcorner fred & flo': {'brand': 'crispcorner fred & flo'},
#  'dr browns': {'brand': 'dr browns'},
#  'dr johnsons': {'brand': 'dr johnsons'},
#  'griptight': {'brand': 'griptight'},
#  'koko': {'brand': 'koko'},
#  'mam': {'brand': 'mam'},
#  'milton': {'brand': 'milton'},
#  'mothercare': {'brand': 'mothercare'},
#  'munchkin': {'brand': 'munchkin'},
#  'ting': {'brand': 'ting'},
#  'tranquini': {'brand': 'tranquini'},
#  'trip': {'brand': 'trip'},
#  'tropical sun': {'brand': 'tropical sun'},
#  'vibrantmart simply': {'brand': 'vibrantmart simply'},
#  'virgils': {'brand': 'virgils'},
#  'vit hit': {'brand': 'vit hit'},
#  'aloe fresh': {'brand': 'aloe fresh'},
#  'big time': {'brand': 'big time'},
#  'calypso': {'brand': 'calypso'},
#  'caprio': {'brand': 'caprio'},
#  'drink 420': {'brand': 'drink 420'},
#  'euro shopper': {'brand': 'euro shopper'},
#  'funke monkee': {'brand': 'funke monkee'},
#  'oasis': {'brand': 'oasis'},
#  'rochester': {'brand': 'rochester'},
#  'simply': {'brand': 'simply'},
#  'squeeze it': {'brand': 'squeeze it'},
#  'sukie': {'brand': 'sukie'},
#  'thirsty': {'brand': 'thirsty'},
#  'this juicy water': {'brand': 'this juicy water'},
#  'trinketto': {'brand': 'trinketto'},
#  'unrooted': {'brand': 'unrooted'},
#  'alo': {'brand': 'alo'},
#  'aloe drink for life': {'brand': 'aloe drink for life'},
#  'appletiser': {'brand': 'appletiser'},
#  'arizona': {'brand': 'arizona'},
#  'beet it': {'brand': 'beet it'},
#  'belvoir': {'brand': 'belvoir'},
#  'benefit drinks': {'brand': 'benefit drinks'},
#  'big tom': {'brand': 'big tom'},
#  'britvic 55': {'brand': 'britvic 55'},
#  'britvic j 20': {'brand': 'britvic j 20'},
#  'campbells non alchlc bvrgs': {'brand': 'campbells non alchlc bvrgs'},
#  'cawston press': {'brand': 'cawston press'},
#  ...}

# %%
train_data = train_data.drop(columns=["price", "retailer", "group", "supergroup", "int_price", "mod_grp_sg"])

# %%
train_data
# Out:
#         indoml_id                 description      module        brand  \
# 0               0                    1 adblue  automotive  receipt all
# 1               1               1 car mat set  automotive  receipt all
# 2               2           1 cp rmx scrnwash  automotive  receipt all
# 3               3                    1 diesel  automotive  receipt all
# 4               4      1 unstoppable refrsher  automotive  receipt all
# ...           ...                         ...         ...          ...
# 561833     561833       zuru xshot excelxcess        toys  receipt all
# 561834     561834            zuru xshot micro        toys  receipt all
# 561835     561835  zuru xshot typhoon thunder        toys  receipt all
# 561836     561836                       zzand        toys  receipt all
# 561837     561837   zzand sand set dinounicon        toys  receipt all
#
#                                                     query
# 0       retailer: organicorner price: 25 description: ...
# 1       retailer: greenharbor price: 4 description: 1 ...
# 2       retailer: naturify price: 3 description: 1 cp ...
# 3         retailer: ecogro price: 4 description: 1 diesel
# 4       retailer: greenharbor price: 3 description: 1 ...
# ...                                                   ...
# 561833  retailer: noshify price: 16 description: zuru ...
# 561834  retailer: vitalveg price: 3 description: zuru ...
# 561835  retailer: crispcorner price: 8 description: zu...
# 561836     retailer: snackify price: 4 description: zzand
# 561837  retailer: noshify price: 6 description: zzand ...
#
# [561838 rows x 5 columns]

# %%
# shuffles dataset
train_data = train_data.sample(frac=1, random_state=42)
train_data = train_data.reset_index(drop=True)

# %%
# create a document of product descriptions which is module + brand fusion
train_data["sup_doc"] = train_data["module"] + "<|>" + train_data["brand"]

# %%
# for each module brand pair, add all queries that correspond to that pair

doc_query_lst = {}
for i, row in train_data.iterrows():
    doc_query = row["sup_doc"]
    if doc_query in doc_query_lst:
        doc_query_lst[doc_query].append(row["query"])
    else:
        doc_query_lst[doc_query] = [row["query"]]

# %%
import random

# %%
train_final = {"query": [], "brand": [], "module": []}
val_final = {"query": [], "brand": [], "module": []}

for doc, query_lst in doc_query_lst.items():
    train_split = max(round(0.97*len(query_lst)), 1)
    random.shuffle(query_lst)
    train_q = query_lst[:train_split]
    val_q = query_lst[train_split:]

    brand = doc.split("<|>")[1]
    module = doc.split("<|>")[0]

    brs = [brand]*len(train_q)
    mods = [module]*len(train_q)

    v_brs = [brand]*len(val_q)
    v_mods = [module]*len(val_q)

    train_final["query"].extend(train_q)
    train_final["brand"].extend(brs)
    train_final["module"].extend(mods)

    val_final["query"].extend(val_q)
    val_final["brand"].extend(v_brs)
    val_final["module"].extend(v_mods)

# %%
train_final_df = pd.DataFrame(train_final)
val_final_df = pd.DataFrame(val_final)

# %%
train_final_df
# Out:
#                                                     query         brand  \
# 0       retailer: vibrantmart price: 2 description: ba...   receipt all
# 1       retailer: wilko price: 3 description: scratchc...   receipt all
# 2       retailer: plenify price: 1 description: easter...   receipt all
# 3       retailer: orchidora price: 1 description: plan...   receipt all
# 4       retailer: greenzen price: 2 description: whs a...   receipt all
# ...                                                   ...           ...
# 546159  retailer: groveify price: 1 description: prime...        primeo
# 546160    retailer: tastify price: 0 description: qatcake  north staffs
# 546161  retailer: vivify price: 0 description: koko df...          koko
# 546162     retailer: snackify price: 5 description: sosft       so soft
# 546163  retailer: nutriglo price: 1 description: paedi...    paediasure
#
#                                                    module
# 0                stationery & printed material & services
# 1                stationery & printed material & services
# 2                stationery & printed material & services
# 3                stationery & printed material & services
# 4                stationery & printed material & services
# ...                                                   ...
# 546159                                    cheese fresh fw
# 546160                           sweet pastry dough fresh
# 546161                                    cheese fresh fw
# 546162                                      toilet tissue
# 546163  vitamins & minerals & nutritional & health sup...
#
# [546164 rows x 3 columns]

# %%
train_final_df = train_final_df.sample(frac=1, random_state=42)
train_final_df = train_final_df.reset_index(drop=True)

# %%
train_final_df.to_csv("_train.csv", index=False)
val_final_df.to_csv("_val.csv", index=False)

# %% [markdown]
# # Encode Docs

# %%
from sentence_transformers import SentenceTransformer
# Out:
# /raid/kavin-intern-maunendra/anaconda3/envs/wow/lib/python3.10/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
model = SentenceTransformer('all-mpnet-base-v2')

# %%
import pickle
doc_mod = train_final_df["module"].unique()
doc_br = train_final_df["brand"].unique()

# %%
mod_id = {}
br_id = {}

for i, doc in enumerate(doc_mod):
    mod_id[doc] = i

for i, doc in enumerate(doc_br):
    br_id[doc] = i

with open("mod_id.pkl", "wb") as f:
    pickle.dump(mod_id, f)

with open("br_id.pkl", "wb") as f:
    pickle.dump(br_id, f)

# %%
dct_id_mod = {"doc": doc_mod, "id": list(range(len(doc_mod)))}
dct_df_mod = pd.DataFrame(dct_id_mod)

dct_id_br = {"doc": doc_br, "id": list(range(len(doc_br)))}
dct_df_br = pd.DataFrame(dct_id_br)

# %%
batched_mod = [doc_mod[i:i+128] for i in range(0, len(doc_mod), 128)]
batched_br = [doc_br[i:i+128] for i in range(0, len(doc_br), 128)]

# %%
from tqdm import tqdm
embeddings_mod = []
embeddings_br = []

for batch in tqdm(batched_mod):
    embeddings_mod.extend(model.encode(batch))

for batch in tqdm(batched_br):
    embeddings_br.extend(model.encode(batch))
# Out:
# 100%|██████████| 4/4 [00:01<00:00,  3.63it/s]
# 100%|██████████| 45/45 [00:03<00:00, 13.44it/s]

# %%
import numpy as np
embeddings_mod = np.array(embeddings_mod)
embeddings_br = np.array(embeddings_br)

np.save("embeddings_mod.npy", embeddings_mod)
np.save("embeddings_br.npy", embeddings_br)

# %%
dct_df_mod = dct_df_mod.rename(columns={"id": "docid"})
dct_df_mod["vector"] = dct_df_mod["docid"].apply(lambda x: np.array(embeddings_mod[x]))

# %%
dct_df_mod["vector"] = dct_df_mod["vector"].apply(lambda x: "|".join([str(g) for g in x.tolist()]))

# %%
dct_df_mod.to_csv("mod_kmeans.tsv", sep="\t", index=False, header=False)

# %% [markdown]
# # Product Quantisation

# %%
import nanopq
pq = nanopq.PQ(M=12, Ks=48, verbose=True)
# Out:
# M: 12, Ks: 48, metric : <class 'numpy.uint8'>, code_dtype: l2

# %%
pq.fit(vecs=embeddings_br, iter=30, seed=1422)
# Out:
# iter: 30, seed: 1422
# Training the subspace: 0 / 12
# Training the subspace: 1 / 12
# Training the subspace: 2 / 12
# Training the subspace: 3 / 12
# Training the subspace: 4 / 12
# Training the subspace: 5 / 12
# Training the subspace: 6 / 12
# Training the subspace: 7 / 12
# Training the subspace: 8 / 12
# Training the subspace: 9 / 12
# Training the subspace: 10 / 12
# Training the subspace: 11 / 12

# %%
X_code = pq.encode(vecs=embeddings_br)
# Out:
# Encoding the subspace: 0 / 12
# Encoding the subspace: 1 / 12
# Encoding the subspace: 2 / 12
# Encoding the subspace: 3 / 12
# Encoding the subspace: 4 / 12
# Encoding the subspace: 5 / 12
# Encoding the subspace: 6 / 12
# Encoding the subspace: 7 / 12
# Encoding the subspace: 8 / 12
# Encoding the subspace: 9 / 12
# Encoding the subspace: 10 / 12
# Encoding the subspace: 11 / 12

# %%
X_code.shape
# Out:
# (5679, 12)

# %%
print(np.unique(X_code, axis=0).shape)
# Out:
# (5548, 12)

# %%
br_code = {}
for i, doc in enumerate(doc_br):
    br_code[doc] = X_code[i]

# %%
with open("br_code.pkl", "wb") as f:
    pickle.dump(br_code, f)

# %% [markdown]
# # Kmeans

# %% [markdown]
# Reused from the Neural Corpus Indexer Repository

# %%
from sklearn.cluster import KMeans
from sklearn.cluster import MiniBatchKMeans
import numpy as np
import pandas as pd
import pickle

args = {"v_dim": 768, "bert_size": 768, "seed": 7, "k": 6, "c": 6}

# %%
#  convert args to object
class Struct:
    def __init__(self, **entries):
        self.__dict__.update(entries)

args = Struct(**args)

# %%
df = pd.read_csv(f'mod_kmeans.tsv',
                 names=['doc', 'docid', 'vector'],
                 header=None, sep='\t').loc[:, ['docid', 'vector']]
df.drop_duplicates('docid', inplace = True)
old_id = df['docid'].tolist()
X = df['vector'].tolist()
for idx,v in enumerate(X):
    vec_str = v.split('|')
    if len(vec_str) != args.v_dim:
        print('vec dim error!')
        print(len(vec_str))
        print(vec_str)
        exit(1)
    X[idx] = [float(v) for v in vec_str]
X = np.array(X)
print(X.shape)
new_id_list = []

kmeans = KMeans(n_clusters=args.k, max_iter=300, n_init=100, init='k-means++', random_state=args.seed, tol=1e-7)

mini_kmeans = MiniBatchKMeans(n_clusters=args.k, max_iter=300, n_init=100, init='k-means++', random_state=3,
                              batch_size=1000, reassignment_ratio=0.01, max_no_improvement=20, tol=1e-7)


def classify_recursion(x_data_pos):
    if x_data_pos.shape[0] <= args.c:
        if x_data_pos.shape[0] == 1:
            return
        for idx, pos in enumerate(x_data_pos):
            new_id_list[pos].append(idx)
        return

    temp_data = np.zeros((x_data_pos.shape[0], args.v_dim))
    for idx, pos in enumerate(x_data_pos):
        temp_data[idx, :] = X[pos]

    if x_data_pos.shape[0] >= 1e3:
        pred = mini_kmeans.fit_predict(temp_data)
    else:
        pred = kmeans.fit_predict(temp_data)

    for i in range(args.k):
        pos_lists = []
        for id_, class_ in enumerate(pred):
            if class_ == i:
                pos_lists.append(x_data_pos[id_])
                new_id_list[x_data_pos[id_]].append(i)
        classify_recursion(np.array(pos_lists))

    return

print('Start First Clustering')
pred = mini_kmeans.fit_predict(X)
print(pred.shape)   #int 0-9 for each vector
print(mini_kmeans.n_iter_)

for class_ in pred:
    new_id_list.append([class_])

print('Start Recursively Clustering...')
for i in range(args.k):
    print(i, "th cluster")
    pos_lists = []
    for id_, class_ in enumerate(pred):
        if class_ == i:
            pos_lists.append(id_)
    classify_recursion(np.array(pos_lists))

mapping = {}
for i in range(len(old_id)):
    mapping[old_id[i]] = new_id_list[i]

with open(f'IDMapping_NQ_bert_{args.bert_size}_k{args.k}_c{args.c}_seed_{args.seed}.pkl', 'wb') as f:
    pickle.dump(mapping, f)
# Out:
# (449, 768)
# Start First Clustering
# (449,)
# 36
# Start Recursively Clustering...
# 0 th cluster
# 1 th cluster
# 2 th cluster
# 3 th cluster
# 4 th cluster
# 5 th cluster

# %%
with open(f'IDMapping_NQ_bert_{args.bert_size}_k{args.k}_c{args.c}_seed_{args.seed}.pkl', "rb") as f:
    docid = pickle.load(f)

# %%
docid
# Out:
# {0: [1, 1, 0, 5, 0],
#  1: [0, 5, 0],
#  2: [1, 2, 1, 0],
#  3: [1, 2, 3, 1],
#  4: [1, 4, 5, 1, 0],
#  5: [3, 2, 0],
#  6: [3, 0, 0, 0],
#  7: [5, 1, 1, 0],
#  8: [1, 4, 5, 4],
#  9: [5, 4, 0],
#  10: [5, 5, 0],
#  11: [5, 4, 3],
#  12: [5, 0, 2, 0],
#  13: [5, 2, 2, 0],
#  14: [1, 0, 3, 0],
#  15: [5, 3, 0, 0],
#  16: [5, 0, 0, 0],
#  17: [0, 5, 1],
#  18: [2, 5, 0, 0],
#  19: [1, 2, 3, 2, 0],
#  20: [1, 4, 5, 1, 1],
#  21: [2, 0, 4, 0],
#  22: [3, 4, 0, 0],
#  23: [5, 5, 1],
#  24: [2, 1, 3, 0],
#  25: [1, 2, 1, 1],
#  26: [4, 1, 0],
#  27: [5, 2, 3],
#  28: [1, 4, 1, 0],
#  29: [3, 4, 0, 1],
#  30: [1, 0, 3, 1],
#  31: [1, 1, 5, 0],
#  32: [5, 1, 2],
#  33: [1, 3, 0, 1, 0],
#  34: [1, 4, 5, 0],
#  35: [1, 2, 2, 0],
#  36: [3, 3, 2],
#  37: [2, 0, 0, 0],
#  38: [1, 1, 2, 0],
#  39: [2, 3, 1, 0],
#  40: [1, 1, 0, 3],
#  41: [1, 5, 2, 0],
#  42: [1, 2, 4, 0],
#  43: [5, 1, 1, 1],
#  44: [0, 2, 2],
#  45: [5, 3, 5, 0],
#  46: [1, 5, 4, 0],
#  47: [5, 0, 2, 1],
#  48: [1, 1, 0, 4, 0],
#  49: [1, 1, 0, 4, 1],
#  50: [5, 0, 3, 0],
#  51: [3, 3, 3, 0],
#  52: [1, 2, 2, 4, 0],
#  53: [5, 0, 2, 2],
#  54: [1, 4, 1, 1],
#  55: [3, 1, 3, 0],
#  56: [1, 0, 5, 0],
#  57: [4, 0, 0],
#  58: [1, 1, 0, 2, 0],
#  59: [3, 1, 5, 0],
#  60: [5, 1, 0],
#  61: [2, 1, 3, 1],
#  62: [5, 4, 5],
#  63: [3, 5, 2, 0],
#  64: [1, 2, 1, 2],
#  65: [5, 2, 0, 0],
#  66: [1, 5, 0, 0],
#  67: [2, 1, 0, 0],
#  68: [3, 5, 0, 0],
#  69: [1, 2, 2, 3],
#  70: [5, 1, 3],
#  71: [2, 0, 1, 0],
#  72: [3, 5, 2, 1],
#  73: [0, 2, 0],
#  74: [1, 1, 5, 1],
#  75: [1, 2, 3, 4],
#  76: [4, 0, 1],
#  77: [3, 4, 3, 0],
#  78: [2, 3, 3, 0],
#  79: [1, 1, 5, 2],
#  80: [1, 5, 4, 1],
#  81: [5, 0, 0, 1],
#  82: [5, 0, 3, 1],
#  83: [4, 5, 0],
#  84: [1, 3, 0, 5],
#  85: [2, 4, 3],
#  86: [1, 1, 0, 0, 0],
#  87: [1, 5, 4, 2],
#  88: [1, 1, 1, 0],
#  89: [2, 2, 1],
#  90: [1, 4, 3, 0],
#  91: [1, 2, 1, 3],
#  92: [0, 2, 1, 0, 0],
#  93: [1, 2, 2, 2],
#  94: [4, 0, 2],
#  95: [1, 3, 4, 2, 0],
#  96: [1, 1, 0, 0, 1],
#  97: [4, 5, 2, 0],
#  98: [5, 0, 1, 0],
#  99: [1, 0, 2, 0],
#  100: [2, 2, 2, 0],
#  101: [3, 0, 3, 0],
#  102: [1, 1, 0, 4, 2],
#  103: [5, 0, 4, 0],
#  104: [2, 0, 2],
#  105: [2, 3, 2, 0],
#  106: [0, 2, 1, 5],
#  107: [1, 0, 2, 1],
#  108: [1, 5, 3, 0],
#  109: [2, 1, 1, 0],
#  110: [1, 1, 3, 0],
#  111: [1, 1, 2, 1],
#  112: [0, 2, 3],
#  113: [0, 3, 0],
#  114: [5, 4, 1, 0],
#  115: [1, 1, 4, 0],
#  116: [5, 2, 1, 0],
#  117: [4, 4, 0],
#  118: [1, 4, 1, 2],
#  119: [2, 1, 5, 0],
#  120: [1, 4, 3, 2, 0],
#  121: [5, 1, 4],
#  122: [5, 0, 1, 1],
#  123: [0, 2, 5, 0],
#  124: [1, 4, 1, 3],
#  125: [5, 0, 1, 2],
#  126: [0, 2, 1, 3],
#  127: [1, 4, 5, 1, 2],
#  128: [2, 5, 5],
#  129: [1, 4, 4, 0],
#  130: [1, 1, 0, 1, 0],
#  131: [1, 4, 4, 1],
#  132: [2, 3, 1, 3, 0],
#  133: [3, 4, 3, 1],
#  134: [5, 1, 1, 2],
#  135: [0, 5, 2],
#  136: [3, 0, 2, 0],
#  137: [2, 3, 1, 3, 1],
#  138: [1, 3, 4, 4],
#  139: [2, 3, 5],
#  140: [3, 4, 4],
#  141: [1, 1, 0, 2, 1],
#  142: [0, 2, 1, 2, 0],
#  143: [0, 2, 1, 2, 1],
#  144: [1, 3, 1, 0],
#  145: [1, 4, 2, 0],
#  146: [1, 2, 2, 1],
#  147: [2, 3, 3, 1],
#  148: [1, 0, 5, 1],
#  149: [5, 2, 5, 0],
#  150: [5, 0, 2, 3],
#  151: [1, 4, 5, 5],
#  152: [2, 4, 1, 0],
#  153: [1, 2, 4, 1],
#  154: [3, 1, 0, 0],
#  155: [5, 3, 3],
#  156: [0, 3, 1],
#  157: [1, 0, 0, 0],
#  158: [1, 0, 4, 0],
#  159: [1, 2, 1, 4],
#  160: [1, 2, 4, 2],
#  161: [1, 3, 1, 1],
#  162: [1, 5, 3, 1, 0],
#  163: [0, 2, 1, 0, 1],
#  164: [3, 4, 0, 2],
#  165: [2, 5, 0, 1],
#  166: [5, 5, 2],
#  167: [5, 0, 4, 1],
#  168: [2, 0, 3, 0],
#  169: [4, 0, 3],
#  170: [1, 2, 3, 5],
#  171: [0, 2, 1, 0, 2],
#  172: [4, 5, 5],
#  173: [5, 2, 2, 1],
#  174: [1, 4, 3, 3],
#  175: [5, 4, 1, 1],
#  176: [5, 3, 2],
#  177: [5, 2, 4],
#  178: [4, 4, 1],
#  179: [5, 2, 0, 1],
#  180: [3, 5, 0, 1],
#  181: [1, 1, 5, 3],
#  182: [1, 5, 5, 0],
#  183: [1, 2, 4, 3],
#  184: [1, 5, 5, 1],
#  185: [2, 1, 3, 2],
#  186: [1, 0, 3, 2],
#  187: [3, 1, 3, 1],
#  188: [1, 0, 2, 2],
#  189: [5, 2, 1, 1],
#  190: [3, 1, 4, 0],
#  191: [1, 4, 1, 4],
#  192: [1, 5, 2, 1],
#  193: [5, 1, 1, 3],
#  194: [0, 1, 0],
#  195: [3, 1, 1, 0],
#  196: [3, 5, 1, 0],
#  197: [0, 0, 5],
#  198: [1, 2, 2, 4, 1],
#  199: [5, 0, 4, 2],
#  200: [0, 0, 0],
#  201: [1, 4, 5, 2],
#  202: [2, 3, 1, 4],
#  203: [2, 0, 3, 1],
#  204: [2, 2, 2, 3],
#  205: [1, 5, 3, 3],
#  206: [2, 1, 2],
#  207: [4, 1, 1, 0],
#  208: [3, 5, 1, 1],
#  209: [1, 3, 0, 0, 0],
#  210: [5, 0, 1, 3],
#  211: [5, 2, 5, 1],
#  212: [5, 3, 5, 1],
#  213: [2, 3, 3, 2],
#  214: [4, 0, 4],
#  215: [4, 1, 5],
#  216: [3, 4, 5],
#  217: [2, 0, 1, 1],
#  218: [0, 5, 3],
#  219: [3, 0, 0, 1],
#  220: [3, 1, 0, 1],
#  221: [4, 1, 1, 1],
#  222: [1, 0, 0, 1],
#  223: [1, 4, 3, 5],
#  224: [1, 3, 4, 5],
#  225: [5, 0, 1, 4],
#  226: [3, 3, 5],
#  227: [1, 1, 3, 1],
#  228: [1, 2, 0, 0],
#  229: [1, 4, 0, 0],
#  230: [1, 4, 3, 1],
#  231: [1, 3, 0, 0, 1],
#  232: [0, 2, 4, 0],
#  233: [1, 2, 4, 4],
#  234: [1, 4, 3, 4],
#  235: [5, 3, 1],
#  236: [0, 2, 1, 1],
#  237: [1, 0, 3, 3],
#  238: [1, 0, 4, 1],
#  239: [1, 1, 0, 1, 1],
#  240: [2, 3, 1, 5],
#  241: [1, 3, 0, 4],
#  242: [2, 0, 4, 1],
#  243: [3, 3, 3, 1],
#  244: [5, 5, 3],
#  245: [1, 1, 4, 1],
#  246: [1, 4, 1, 5],
#  247: [1, 5, 5, 2],
#  248: [1, 2, 5, 0],
#  249: [3, 0, 4],
#  250: [2, 5, 1],
#  251: [0, 2, 4, 1],
#  252: [3, 5, 1, 2],
#  253: [2, 4, 2],
#  254: [0, 2, 1, 4],
#  255: [0, 3, 2],
#  256: [1, 5, 1, 0],
#  257: [1, 0, 0, 2],
#  258: [3, 3, 4],
#  259: [1, 1, 4, 2],
#  260: [1, 1, 0, 0, 2],
#  261: [0, 3, 3],
#  262: [3, 2, 2, 0],
#  263: [4, 2, 0],
#  264: [2, 4, 5],
#  265: [0, 0, 2, 0],
#  266: [2, 3, 1, 1],
#  267: [2, 2, 2, 1, 0],
#  268: [1, 5, 2, 2],
#  269: [1, 2, 3, 0, 0],
#  270: [1, 1, 0, 5, 1],
#  271: [0, 2, 5, 1],
#  272: [1, 3, 5],
#  273: [1, 4, 2, 1],
#  274: [1, 5, 0, 1],
#  275: [3, 3, 1, 0],
#  276: [2, 2, 0, 0],
#  277: [2, 0, 3, 2],
#  278: [1, 2, 3, 3],
#  279: [2, 2, 4],
#  280: [0, 1, 1],
#  281: [5, 3, 0, 1],
#  282: [2, 2, 2, 4],
#  283: [3, 5, 5],
#  284: [3, 0, 2, 1],
#  285: [3, 5, 1, 3],
#  286: [5, 0, 0, 2],
#  287: [1, 2, 2, 5],
#  288: [2, 4, 0, 0],
#  289: [3, 1, 2, 0],
#  290: [3, 1, 4, 1],
#  291: [2, 3, 2, 1],
#  292: [0, 0, 4, 0],
#  293: [2, 1, 4],
#  294: [1, 0, 3, 4],
#  295: [1, 5, 4, 3],
#  296: [5, 4, 4],
#  297: [1, 2, 0, 1],
#  298: [1, 3, 1, 2],
#  299: [1, 0, 1, 0],
#  300: [3, 1, 2, 1],
#  301: [1, 3, 1, 3],
#  302: [2, 5, 3],
#  303: [5, 4, 2],
#  304: [1, 2, 5, 1],
#  305: [1, 4, 0, 1],
#  306: [1, 3, 3, 0],
#  307: [3, 3, 0, 0],
#  308: [5, 0, 2, 4],
#  309: [1, 1, 2, 2],
#  310: [4, 5, 2, 1],
#  311: [5, 0, 4, 3],
#  312: [1, 5, 0, 2],
#  313: [2, 3, 4],
#  314: [1, 3, 0, 1, 1],
#  315: [1, 4, 0, 2],
#  316: [3, 5, 2, 2],
#  317: [3, 1, 5, 1],
#  318: [0, 0, 1],
#  319: [2, 2, 3, 0],
#  320: [4, 4, 2],
#  321: [2, 3, 2, 2],
#  322: [2, 0, 0, 1],
#  323: [1, 5, 3, 2],
#  324: [1, 3, 0, 1, 2],
#  325: [4, 5, 1, 0],
#  326: [0, 5, 4],
#  327: [1, 1, 3, 2],
#  328: [1, 4, 4, 2],
#  329: [3, 0, 3, 1],
#  330: [2, 1, 0, 1],
#  331: [1, 5, 2, 3],
#  332: [3, 0, 1],
#  333: [4, 4, 3],
#  334: [1, 0, 1, 1],
#  335: [2, 0, 1, 2],
#  336: [1, 3, 2, 0],
#  337: [2, 1, 0, 2],
#  338: [1, 5, 2, 4],
#  339: [1, 3, 3, 1],
#  340: [2, 1, 5, 1],
#  341: [0, 1, 2],
#  342: [1, 1, 0, 1, 2],
#  343: [3, 2, 5],
#  344: [2, 2, 5],
#  345: [1, 4, 0, 3],
#  346: [3, 2, 1],
#  347: [1, 1, 1, 1],
#  348: [3, 5, 1, 4],
#  349: [3, 2, 2, 1],
#  350: [2, 5, 4],
#  351: [2, 4, 0, 1],
#  352: [0, 4, 0],
#  353: [2, 0, 5],
#  354: [1, 3, 4, 1, 0],
#  355: [5, 0, 5],
#  356: [0, 3, 4],
#  357: [1, 4, 5, 3],
#  358: [4, 3, 0],
#  359: [1, 5, 0, 3],
#  360: [1, 2, 0, 2],
#  361: [2, 3, 1, 2],
#  362: [1, 5, 1, 1],
#  363: [5, 0, 2, 5],
#  364: [1, 4, 5, 1, 3],
#  365: [2, 4, 4],
#  366: [1, 4, 0, 4],
#  367: [3, 1, 0, 2],
#  368: [1, 3, 0, 3],
#  369: [1, 3, 4, 1, 1],
#  370: [3, 0, 5],
#  371: [3, 2, 3],
#  372: [2, 3, 0],
#  373: [0, 0, 2, 1],
#  374: [1, 0, 2, 3],
#  375: [1, 2, 3, 2, 1],
#  376: [2, 2, 2, 5],
#  377: [1, 1, 2, 3],
#  378: [4, 5, 3],
#  379: [3, 3, 1, 1],
#  380: [2, 2, 2, 1, 1],
#  381: [3, 5, 3],
#  382: [4, 5, 4],
#  383: [4, 5, 1, 1],
#  384: [2, 2, 0, 1],
#  385: [3, 4, 1],
#  386: [3, 1, 1, 1],
#  387: [1, 0, 0, 3],
#  388: [1, 2, 3, 0, 1],
#  389: [1, 3, 4, 2, 1],
#  390: [1, 2, 3, 2, 2],
#  391: [1, 1, 1, 2],
#  392: [3, 1, 2, 2],
#  393: [1, 1, 3, 3],
#  394: [1, 4, 3, 2, 1],
#  395: [4, 4, 4],
#  396: [5, 0, 0, 3],
#  397: [2, 1, 0, 3],
#  398: [1, 3, 4, 1, 2],
#  399: [2, 1, 1, 1],
#  400: [1, 3, 4, 0],
#  401: [2, 1, 0, 4],
#  402: [4, 1, 3],
#  403: [1, 2, 5, 2],
#  404: [1, 3, 2, 1],
#  405: [4, 0, 5],
#  406: [5, 3, 4],
#  407: [1, 3, 4, 3],
#  408: [2, 5, 2],
#  409: [4, 1, 4],
#  410: [1, 5, 4, 4],
#  411: [1, 1, 2, 4],
#  412: [4, 3, 1],
#  413: [5, 1, 5],
#  414: [3, 5, 4],
#  415: [0, 0, 4, 1],
#  416: [3, 4, 2],
#  417: [1, 5, 0, 4],
#  418: [1, 5, 4, 5],
#  419: [1, 5, 3, 5],
#  420: [1, 3, 0, 2, 0],
#  421: [3, 3, 0, 1],
#  422: [5, 2, 1, 2],
#  423: [5, 5, 4],
#  424: [2, 2, 2, 2],
#  425: [4, 2, 1],
#  426: [1, 4, 2, 2],
#  427: [3, 1, 0, 3],
#  428: [0, 4, 1],
#  429: [2, 4, 1, 1],
#  430: [1, 5, 0, 5],
#  431: [1, 1, 3, 4],
#  432: [3, 2, 4],
#  433: [3, 1, 4, 2],
#  434: [5, 0, 1, 5],
#  435: [0, 0, 3],
#  436: [1, 5, 3, 1, 1],
#  437: [1, 4, 4, 3],
#  438: [1, 0, 4, 2],
#  439: [1, 3, 0, 2, 1],
#  440: [1, 5, 3, 4],
#  441: [4, 4, 5],
#  442: [4, 1, 2],
#  443: [1, 3, 1, 4],
#  444: [1, 3, 4, 1, 3],
#  445: [2, 2, 3, 1],
#  446: [2, 2, 3, 2],
#  447: [1, 0, 5, 2],
#  448: [1, 5, 2, 5]}

# %%
dv = list(docid.values())

lns = []

for d in dv:
    lns.append(len(d))

# %%
max(lns), min(lns), sum(lns) / len(lns)
# Out:
# (5, 3, 3.8730512249443207)

# %%
with open("mod_id.pkl", "rb") as f:
    mod_id = pickle.load(f)

# %%
mod_id
# Out:
# {'bleach ammonia': 0,
#  'garden & flora': 1,
#  'stationery & printed material & services': 2,
#  'homecare merchandise': 3,
#  'skin conditioning moisturising': 4,
#  'wine still light table styles': 5,
#  'sugar candy': 6,
#  'snacks chips crisps reconstituted extruded': 7,
#  'skin cleansing & toning': 8,
#  'meat products fresh': 9,
#  'dog food dry': 10,
#  'meat cuts joints whole fresh fw': 11,
#  'eggs egg products fresh': 12,
#  'chocolate single variety': 13,
#  'cough cold & other respiratory remedies & accessories': 14,
#  'fruit orange fresh fw': 15,
#  'cheese fresh fw': 16,
#  'vegetables salad vegetables remaining varieties ambient': 17,
#  'milk substitutes non flavoured ambient': 18,
#  'clothing & personal accessories': 19,
#  'skin treatments dermatologicals': 20,
#  'biscuits sweet ambient': 21,
#  'flavoured drinks carbonated non cola': 22,
#  'cat food wet': 23,
#  'vinegar ambient': 24,
#  'home furnishings & decor': 25,
#  'ice cream novelties sorbet yogurt frozen': 26,
#  'yogurt spoonable fresh': 27,
#  'hair conditioners': 28,
#  'flavoured drinks carbonated cola': 29,
#  'allergy hayfever remedies': 30,
#  'toilet tissue': 31,
#  'baby food': 32,
#  'tooth cleaning': 33,
#  'fragrances cologne': 34,
#  'pets & pet care': 35,
#  'bird food drinks': 36,
#  'bread ambient': 37,
#  'auto dish detergent': 38,
#  'nuts ambient': 39,
#  'bath additives': 40,
#  'electronic cigarettes cigars pipes vaporizers': 41,
#  'computing & telecommunications': 42,
#  'snacks chips crisps': 43,
#  'vegetables natural remaining varieties fresh': 44,
#  'fruit berries fresh fw': 45,
#  'slimming aids': 46,
#  'sweet pastry dough fresh': 47,
#  'toilet cleaners fresheners': 48,
#  'carpet fresheners': 49,
#  'cooking sauce fresh': 50,
#  'dog food wet': 51,
#  'pet general accessories': 52,
#  'dough products fresh': 53,
#  'hair shampoo': 54,
#  'sports energy drinks': 55,
#  'calming & sleeping': 56,
#  'fish shellfish seafood prepared frozen fw': 57,
#  'cleansing soap': 58,
#  'beer lager ales': 59,
#  'cereal fruit muesli bars': 60,
#  'mayonnaise ambient': 61,
#  'fish shellfish seafood fresh fw': 62,
#  'juices': 63,
#  'kitchen & tableware': 64,
#  'milk animal non flavoured fresh': 65,
#  'pet flea tick worming products': 66,
#  'hot cooking sauce ambient': 67,
#  'coffee': 68,
#  'cat food treats & gift selections': 69,
#  'bread sandwiches filled rolls wraps': 70,
#  'breakfast cereals ambient': 71,
#  'cigarettes': 72,
#  'herbs spices fresh fw': 73,
#  'sanitary protection': 74,
#  'toys': 75,
#  'meat cuts joints whole frozen fw': 76,
#  'mineral water non carbonated': 77,
#  'noodles ambient': 78,
#  'incontinence': 79,
#  'weight gain products': 80,
#  'bread fresh fw': 81,
#  'dips dressings sauces fresh': 82,
#  'pizza frozen': 83,
#  'mouthwash oral rinses oral rinse antiseptics': 84,
#  'fruit & nut combination dried ambient': 85,
#  'laundry detergents': 86,
#  'deodorants': 87,
#  'laundry special care': 88,
#  'potato products ambient': 89,
#  'lip cosmetics': 90,
#  'home do it yourself': 91,
#  'vegetables natural potatoes fresh fw': 92,
#  'pet fish treatments aquariums accessories': 93,
#  'meat products frozen': 94,
#  'plasters': 95,
#  'textile fresheners': 96,
#  'potato products frozen': 97,
#  'potato meals fresh': 98,
#  'vitamins & minerals & nutritional & health supplements': 99,
#  'meal kits ambient': 100,
#  'chocolate novelties': 101,
#  'household cleaners': 102,
#  'desserts fresh': 103,
#  'cakes gateaux ambient': 104,
#  'desserts ambient': 105,
#  'vegetables natural onion fresh fw': 106,
#  'herbal botanical remedies & treatments & supplements': 107,
#  'air fresheners continuous': 108,
#  'dips dressings sauces ambient': 109,
#  'cleaning cloths': 110,
#  'hand dish detergent': 111,
#  'vegetables salad vegetables frozen': 112,
#  'fruit varieties remaining fresh vw': 113,
#  'protein based meat fish alternatives fresh': 114,
#  'tableware drinkware disposable': 115,
#  'butter marg edible fats fresh': 116,
#  'dough products frozen': 117,
#  'hair styling': 118,
#  'syrup treacle molasses ambient': 119,
#  'face cosmetics': 120,
#  'snacks dipping fresh': 121,
#  'rice fresh': 122,
#  'salads fresh fw': 123,
#  'hair colourants': 124,
#  'pizza fresh': 125,
#  'vegetables natural mushroom fresh fw': 126,
#  'massage products': 127,
#  'meat products ambient': 128,
#  'automotive': 129,
#  'hand sanitizers': 130,
#  'optical': 131,
#  'sugar ambient': 132,
#  'mineral water carbonated': 133,
#  'snacks pretzels': 134,
#  'vegetables tomatoes ambient': 135,
#  'snacks': 136,
#  'fruit ambient': 137,
#  'gloves household': 138,
#  'rice ambient': 139,
#  'tonic water': 140,
#  'cleansing body wash': 141,
#  'vegetables natural cucumber fresh fw': 142,
#  'vegetables natural broccoli cauliflower fresh fw': 143,
#  'nail polish & decoration': 144,
#  'razor blades': 145,
#  'dog chews bones treats & gift selections': 146,
#  'pasta ambient': 147,
#  'nasal decongestant': 148,
#  'cream substitutes fresh': 149,
#  'savoury pastry products fresh': 150,
#  'cotton wool': 151,
#  'nut butter ambient': 152,
#  'cooking appliances & cooking ware': 153,
#  'alcoholic pre mixed drinks': 154,
#  'cakes gateaux fresh fw': 155,
#  'fruit banana fresh vw': 156,
#  'antacids': 157,
#  'general analgesics': 158,
#  'sport & leisure': 159,
#  'home entertainment': 160,
#  'shoe applications polish': 161,
#  'air fresheners instant': 162,
#  'vegetables natural tomatoes fresh fw': 163,
#  'flavoured drinks non carbonated non cola': 164,
#  'milk animal non flavoured ambient': 165,
#  'cat food dry': 166,
#  'cream fresh': 167,
#  'baking mix ambient': 168,
#  'fish shellfish seafood natural frozen fw': 169,
#  'personal care combination & travel packs': 170,
#  'vegetables natural carrot fresh fw': 171,
#  'rice frozen': 172,
#  'chocolate assorted inc multipack': 173,
#  'facial tissues': 174,
#  'protein based meat fish alternatives frzn': 175,
#  'fruit apple pear family fresh fw': 176,
#  'specialist combination packs fresh': 177,
#  'sweet pastry dough frozen': 178,
#  'milk substitutes non flavoured fresh': 179,
#  'tea': 180,
#  'baby diapers': 181,
#  'herbs spices': 182,
#  'home appliances': 183,
#  'candles non scented': 184,
#  'ketchup ambient': 185,
#  'cold flu remedies': 186,
#  'sports energy sweets bars': 187,
#  'digestive & liver & other intestinal remedies': 188,
#  'blended fats spreads fresh': 189,
#  'concentrates cordial squashes syrups': 190,
#  'hair care': 191,
#  'anti smoking products': 192,
#  'snacks chips crisps tortilla': 193,
#  'meat meat products fresh vw': 194,
#  'coffee rtd': 195,
#  'brandy': 196,
#  'vegetables natural peppers fresh vw': 197,
#  'pet litter & litter accessories': 198,
#  'butter fresh': 199,
#  'vegetables natural onion fresh vw': 200,
#  'shaving cream foam gel oil': 201,
#  'seeds ambient': 202,
#  'sweet pastry dough ambient': 203,
#  'confectionery spreads ambient': 204,
#  'bags refuse': 205,
#  'chutney pickle relish ambient': 206,
#  'cakes gateaux frozen': 207,
#  'whisky': 208,
#  'toothbrushes manual': 209,
#  'pasta fresh': 210,
#  'fillings pastes spreads savoury fresh': 211,
#  'fruit mixed fruit fresh fw': 212,
#  'soup ambient': 213,
#  'fish fingers frozen fw': 214,
#  'fruit frozen': 215,
#  'cider': 216,
#  'breadsticks crispbread cereal based cakes ambient': 217,
#  'vegetables beans pods pulses exc rice ambient': 218,
#  'sugar candy gum': 219,
#  'flavoured aperitifs mixers bitter fruits ginger ale': 220,
#  'desserts frozen': 221,
#  'travel motion sickness products': 222,
#  'eye cosmetics': 223,
#  'abrasive cleaning pads': 224,
#  'noodles fresh': 225,
#  'milk animal flavoured drinks': 226,
#  'cleaning scourers pads sponges': 227,
#  'baby feeding accessories': 228,
#  'sun protection': 229,
#  'eye care': 230,
#  'toothbrushes electric': 231,
#  'vegetables reconstituted prdcts frzn': 232,
#  'personal care appliances': 233,
#  'cosmetic removal': 234,
#  'fruit varieties remaining fresh fw': 235,
#  'vegetables natural lettuce mixed leaves fresh fw': 236,
#  'cough remedies': 237,
#  'muscular pain relief': 238,
#  'household disinfectants': 239,
#  'honey ambient': 240,
#  'dental accessories': 241,
#  'savoury biscuits crackers ambient': 242,
#  'pet food': 243,
#  'reptile food': 244,
#  'kitchen paper towel disposable': 245,
#  'hair fixing temporary': 246,
#  'candles scented': 247,
#  'baby healthcare': 248,
#  'baby formula': 249,
#  'fish shellfish seafood ambient': 250,
#  'vegetables reconstituted products fresh': 251,
#  'vodka': 252,
#  'bouillon stock ambient': 253,
#  'vegetables natural peppers fresh fw': 254,
#  'fruit apple pear family fresh vw': 255,
#  'circulatory products': 256,
#  'depilatories': 257,
#  'small mammal food drinks': 258,
#  'kitchenware disposable': 259,
#  'fabric softeners': 260,
#  'fruit orange fresh vw': 261,
#  'wine sparkling': 262,
#  'soup stock bouillon fresh': 263,
#  'cooking edible oils ambient': 264,
#  'vegetables natural broccoli cauliflower fresh vw': 265,
#  'jams marmalade ambient': 266,
#  'dessert mix ambient': 267,
#  'smoking accessories': 268,
#  'cosmetic combination packs & gift sets': 269,
#  'household stain removers': 270,
#  'vegetables salad vegetables fresh fw': 271,
#  'household limescale mildew mould': 272,
#  'razors': 273,
#  'head lice products treatments': 274,
#  'cat milk drinks': 275,
#  'prepared coatings decoration icings frostings ambient': 276,
#  'flour ambient': 277,
#  'first aid & medical surgical supplies': 278,
#  'specialist combination packs ambient': 279,
#  'fish shellfish seafood fresh vw': 280,
#  'fruit citrus fresh fw': 281,
#  'ingredients decorating ambient': 282,
#  'salt': 283,
#  'snacks popcorn': 284,
#  'gin': 285,
#  'biscuits sweet fresh': 286,
#  'pet hygiene & grooming': 287,
#  'sugar substitutes ambient': 288,
#  'yogurt yogurt substitute drinking': 289,
#  'infusions fruit herbal': 290,
#  'creamers ambient': 291,
#  'vegetables natural potatoes fresh vw': 292,
#  'auto dish salt': 293,
#  'sore throat remedies': 294,
#  'diarrhoea products': 295,
#  'combined meat fish seafood products fresh': 296,
#  'baby soothing hardware': 297,
#  'polish furniture surface': 298,
#  'cold sore treatments': 299,
#  'fermented milk milk substitute drinking': 300,
#  'nail care': 301,
#  'protein based meat fish alternatives ambient': 302,
#  'fish food': 303,
#  'healthcare': 304,
#  'aftershave': 305,
#  'contact lens care': 306,
#  'dog food drinks': 307,
#  'dough fresh': 308,
#  'dish pre wash treatment booster': 309,
#  'potato meals frozen': 310,
#  'margarine fresh': 311,
#  'insect control': 312,
#  'polenta ambient': 313,
#  'tooth stain removers': 314,
#  'self tan': 315,
#  'cigars': 316,
#  'beer lager ales low non alcoholic': 317,
#  'vegetables salad vegetables fresh vw': 318,
#  'fillings pastes spreads savoury ambient': 319,
#  'savoury pastry products frozen': 320,
#  'cheese ambient': 321,
#  'stuffing bread based ambient': 322,
#  'air treatments non electrical': 323,
#  'denture brushes cleansers fixatives': 324,
#  'pasta frozen': 325,
#  'vegetables potatoes ambient': 326,
#  'toilet cleaning system': 327,
#  'photo': 328,
#  'chocolate drinks': 329,
#  'dessert sauces ambient': 330,
#  'heat not burn cigarettes': 331,
#  'pepper peppercorns': 332,
#  'bread frozen': 333,
#  'oral treatment': 334,
#  'breakfast cereals toaster pastries ambient': 335,
#  'foot heel toe caps cushions pads': 336,
#  'mint sauce ambient': 337,
#  'tobacco snuff': 338,
#  'ear care': 339,
#  'couscous ambient': 340,
#  'cheese fresh vw': 341,
#  'antiseptic products': 342,
#  'liqueurs': 343,
#  'raising agents ambient': 344,
#  'tan accelerators': 345,
#  'wine fortified styles': 346,
#  'intimate wash': 347,
#  'rum': 348,
#  'wine champagne': 349,
#  'milk evaporated condensed ambient': 350,
#  'combined carbohydrate products ambient': 351,
#  'vegetables with meat fish additives ambient': 352,
#  'potato meals ambient': 353,
#  'foot care hygiene': 354,
#  'raising agents fresh': 355,
#  'fruit citrus fresh vw': 356,
#  'intimate lubrication': 357,
#  'pizza bases kits frozen': 358,
#  'pet deterrents attractants': 359,
#  'breast feeding accessories': 360,
#  'mustard ambient': 361,
#  'joint products': 362,
#  'pizza bases kits fresh': 363,
#  'grooming bathing aids': 364,
#  'prepared bases unfilled ambient': 365,
#  'aftersun': 366,
#  'beer & flavoured drink mixes': 367,
#  'dental floss tape': 368,
#  'shoe applications deodoriser disinfectant': 369,
#  'cocoa powder': 370,
#  'beer wine spirit making kits': 371,
#  'salads ready to eat ambient': 372,
#  'vegetables natural carrot fresh vw': 373,
#  'homeopathic remedies treatments': 374,
#  'shoe accessories': 375,
#  'ingredients ambient': 376,
#  'auto dish rinse aid': 377,
#  'herbs spices frozen': 378,
#  'cat food drinks': 379,
#  'recipe mixes ambient': 380,
#  'spirits remaining': 381,
#  'potato gnocchi fresh': 382,
#  'noodles frozen': 383,
#  'prepared coatings marzipan almond paste ambient': 384,
#  'soda water': 385,
#  'coffee substitutes': 386,
#  'laxatives': 387,
#  'confectionery & gift confectionery & novelty': 388,
#  'wound dressing': 389,
#  'cosmetic accessories': 390,
#  'laundry colour care': 391,
#  'milk substitutes flavoured drinks': 392,
#  'cleaning system cloths dusters': 393,
#  'body body & face cosmetics': 394,
#  'dough frozen': 395,
#  'stuffing bread based fresh': 396,
#  'tartare sauce ambient': 397,
#  'shoe applications cleaners': 398,
#  'marinades ambient': 399,
#  'insect bite treatments': 400,
#  'seafood cocktail sauce ambient': 401,
#  'ice frozen': 402,
#  'baby care': 403,
#  'foot insoles': 404,
#  'fish shellfish seafood frozen fw': 405,
#  'fruit nuts fresh fw': 406,
#  'pipe openers treatments': 407,
#  'eggs egg products ambient': 408,
#  'dips dressings sauces frozen': 409,
#  'genito urinary system & contraceptive products': 410,
#  'auto dish washer fresheners': 411,
#  'specialist combination packs frozen': 412,
#  'biscuits & confectionery & snacks assortments': 413,
#  'stimulants': 414,
#  'vegetables natural tomatoes fresh vw': 415,
#  'cider low non alcoholic': 416,
#  'insect repellents personal': 417,
#  'contraceptive products': 418,
#  'air fresheners refrigerator': 419,
#  'mouth care': 420,
#  'dog milk drinks': 421,
#  'combined carbohydrate products fresh': 422,
#  'marinades dry': 423,
#  'pizza bases kits ambient': 424,
#  'soup stock bouillon frozen': 425,
#  'shaving depilation': 426,
#  'malted drinks': 427,
#  'vegetables with meat fish additives frzn': 428,
#  'butter marg edible fats ambient': 429,
#  'pest control': 430,
#  'cleaning system floor mops refills': 431,
#  'spirits minor regional styles': 432,
#  'tea & infusions assortment': 433,
#  'couscous fresh': 434,
#  'vegetables natural lettuce mixed leaves fresh vw': 435,
#  'breath fresheners': 436,
#  'brain & nervous system': 437,
#  'pain relief': 438,
#  'oral hygiene': 439,
#  'air fresheners vacuum cleaners': 440,
#  'stuffing bread based frozen': 441,
#  'cheese frozen': 442,
#  'polish metal': 443,
#  'shoe applications waterproofing dubbin': 444,
#  'thickening agent ambient': 445,
#  'cream substitutes ambient': 446,
#  'anti snore treatments': 447,
#  'breathing aids nasal strips': 448}

# %%
mod_code = {k: np.array(docid[v]) for k, v in mod_id.items()}

# %%
mod_code
# Out:
# {'bleach ammonia': array([1, 1, 0, 5, 0]),
#  'garden & flora': array([0, 5, 0]),
#  'stationery & printed material & services': array([1, 2, 1, 0]),
#  'homecare merchandise': array([1, 2, 3, 1]),
#  'skin conditioning moisturising': array([1, 4, 5, 1, 0]),
#  'wine still light table styles': array([3, 2, 0]),
#  'sugar candy': array([3, 0, 0, 0]),
#  'snacks chips crisps reconstituted extruded': array([5, 1, 1, 0]),
#  'skin cleansing & toning': array([1, 4, 5, 4]),
#  'meat products fresh': array([5, 4, 0]),
#  'dog food dry': array([5, 5, 0]),
#  'meat cuts joints whole fresh fw': array([5, 4, 3]),
#  'eggs egg products fresh': array([5, 0, 2, 0]),
#  'chocolate single variety': array([5, 2, 2, 0]),
#  'cough cold & other respiratory remedies & accessories': array([1, 0, 3, 0]),
#  'fruit orange fresh fw': array([5, 3, 0, 0]),
#  'cheese fresh fw': array([5, 0, 0, 0]),
#  'vegetables salad vegetables remaining varieties ambient': array([0, 5, 1]),
#  'milk substitutes non flavoured ambient': array([2, 5, 0, 0]),
#  'clothing & personal accessories': array([1, 2, 3, 2, 0]),
#  'skin treatments dermatologicals': array([1, 4, 5, 1, 1]),
#  'biscuits sweet ambient': array([2, 0, 4, 0]),
#  'flavoured drinks carbonated non cola': array([3, 4, 0, 0]),
#  'cat food wet': array([5, 5, 1]),
#  'vinegar ambient': array([2, 1, 3, 0]),
#  'home furnishings & decor': array([1, 2, 1, 1]),
#  'ice cream novelties sorbet yogurt frozen': array([4, 1, 0]),
#  'yogurt spoonable fresh': array([5, 2, 3]),
#  'hair conditioners': array([1, 4, 1, 0]),
#  'flavoured drinks carbonated cola': array([3, 4, 0, 1]),
#  'allergy hayfever remedies': array([1, 0, 3, 1]),
#  'toilet tissue': array([1, 1, 5, 0]),
#  'baby food': array([5, 1, 2]),
#  'tooth cleaning': array([1, 3, 0, 1, 0]),
#  'fragrances cologne': array([1, 4, 5, 0]),
#  'pets & pet care': array([1, 2, 2, 0]),
#  'bird food drinks': array([3, 3, 2]),
#  'bread ambient': array([2, 0, 0, 0]),
#  'auto dish detergent': array([1, 1, 2, 0]),
#  'nuts ambient': array([2, 3, 1, 0]),
#  'bath additives': array([1, 1, 0, 3]),
#  'electronic cigarettes cigars pipes vaporizers': array([1, 5, 2, 0]),
#  'computing & telecommunications': array([1, 2, 4, 0]),
#  'snacks chips crisps': array([5, 1, 1, 1]),
#  'vegetables natural remaining varieties fresh': array([0, 2, 2]),
#  'fruit berries fresh fw': array([5, 3, 5, 0]),
#  'slimming aids': array([1, 5, 4, 0]),
#  'sweet pastry dough fresh': array([5, 0, 2, 1]),
#  'toilet cleaners fresheners': array([1, 1, 0, 4, 0]),
#  'carpet fresheners': array([1, 1, 0, 4, 1]),
#  'cooking sauce fresh': array([5, 0, 3, 0]),
#  'dog food wet': array([3, 3, 3, 0]),
#  'pet general accessories': array([1, 2, 2, 4, 0]),
#  'dough products fresh': array([5, 0, 2, 2]),
#  'hair shampoo': array([1, 4, 1, 1]),
#  'sports energy drinks': array([3, 1, 3, 0]),
#  'calming & sleeping': array([1, 0, 5, 0]),
#  'fish shellfish seafood prepared frozen fw': array([4, 0, 0]),
#  'cleansing soap': array([1, 1, 0, 2, 0]),
#  'beer lager ales': array([3, 1, 5, 0]),
#  'cereal fruit muesli bars': array([5, 1, 0]),
#  'mayonnaise ambient': array([2, 1, 3, 1]),
#  'fish shellfish seafood fresh fw': array([5, 4, 5]),
#  'juices': array([3, 5, 2, 0]),
#  'kitchen & tableware': array([1, 2, 1, 2]),
#  'milk animal non flavoured fresh': array([5, 2, 0, 0]),
#  'pet flea tick worming products': array([1, 5, 0, 0]),
#  'hot cooking sauce ambient': array([2, 1, 0, 0]),
#  'coffee': array([3, 5, 0, 0]),
#  'cat food treats & gift selections': array([1, 2, 2, 3]),
#  'bread sandwiches filled rolls wraps': array([5, 1, 3]),
#  'breakfast cereals ambient': array([2, 0, 1, 0]),
#  'cigarettes': array([3, 5, 2, 1]),
#  'herbs spices fresh fw': array([0, 2, 0]),
#  'sanitary protection': array([1, 1, 5, 1]),
#  'toys': array([1, 2, 3, 4]),
#  'meat cuts joints whole frozen fw': array([4, 0, 1]),
#  'mineral water non carbonated': array([3, 4, 3, 0]),
#  'noodles ambient': array([2, 3, 3, 0]),
#  'incontinence': array([1, 1, 5, 2]),
#  'weight gain products': array([1, 5, 4, 1]),
#  'bread fresh fw': array([5, 0, 0, 1]),
#  'dips dressings sauces fresh': array([5, 0, 3, 1]),
#  'pizza frozen': array([4, 5, 0]),
#  'mouthwash oral rinses oral rinse antiseptics': array([1, 3, 0, 5]),
#  'fruit & nut combination dried ambient': array([2, 4, 3]),
#  'laundry detergents': array([1, 1, 0, 0, 0]),
#  'deodorants': array([1, 5, 4, 2]),
#  'laundry special care': array([1, 1, 1, 0]),
#  'potato products ambient': array([2, 2, 1]),
#  'lip cosmetics': array([1, 4, 3, 0]),
#  'home do it yourself': array([1, 2, 1, 3]),
#  'vegetables natural potatoes fresh fw': array([0, 2, 1, 0, 0]),
#  'pet fish treatments aquariums accessories': array([1, 2, 2, 2]),
#  'meat products frozen': array([4, 0, 2]),
#  'plasters': array([1, 3, 4, 2, 0]),
#  'textile fresheners': array([1, 1, 0, 0, 1]),
#  'potato products frozen': array([4, 5, 2, 0]),
#  'potato meals fresh': array([5, 0, 1, 0]),
#  'vitamins & minerals & nutritional & health supplements': array([1, 0, 2, 0]),
#  'meal kits ambient': array([2, 2, 2, 0]),
#  'chocolate novelties': array([3, 0, 3, 0]),
#  'household cleaners': array([1, 1, 0, 4, 2]),
#  'desserts fresh': array([5, 0, 4, 0]),
#  'cakes gateaux ambient': array([2, 0, 2]),
#  'desserts ambient': array([2, 3, 2, 0]),
#  'vegetables natural onion fresh fw': array([0, 2, 1, 5]),
#  'herbal botanical remedies & treatments & supplements': array([1, 0, 2, 1]),
#  'air fresheners continuous': array([1, 5, 3, 0]),
#  'dips dressings sauces ambient': array([2, 1, 1, 0]),
#  'cleaning cloths': array([1, 1, 3, 0]),
#  'hand dish detergent': array([1, 1, 2, 1]),
#  'vegetables salad vegetables frozen': array([0, 2, 3]),
#  'fruit varieties remaining fresh vw': array([0, 3, 0]),
#  'protein based meat fish alternatives fresh': array([5, 4, 1, 0]),
#  'tableware drinkware disposable': array([1, 1, 4, 0]),
#  'butter marg edible fats fresh': array([5, 2, 1, 0]),
#  'dough products frozen': array([4, 4, 0]),
#  'hair styling': array([1, 4, 1, 2]),
#  'syrup treacle molasses ambient': array([2, 1, 5, 0]),
#  'face cosmetics': array([1, 4, 3, 2, 0]),
#  'snacks dipping fresh': array([5, 1, 4]),
#  'rice fresh': array([5, 0, 1, 1]),
#  'salads fresh fw': array([0, 2, 5, 0]),
#  'hair colourants': array([1, 4, 1, 3]),
#  'pizza fresh': array([5, 0, 1, 2]),
#  'vegetables natural mushroom fresh fw': array([0, 2, 1, 3]),
#  'massage products': array([1, 4, 5, 1, 2]),
#  'meat products ambient': array([2, 5, 5]),
#  'automotive': array([1, 4, 4, 0]),
#  'hand sanitizers': array([1, 1, 0, 1, 0]),
#  'optical': array([1, 4, 4, 1]),
#  'sugar ambient': array([2, 3, 1, 3, 0]),
#  'mineral water carbonated': array([3, 4, 3, 1]),
#  'snacks pretzels': array([5, 1, 1, 2]),
#  'vegetables tomatoes ambient': array([0, 5, 2]),
#  'snacks': array([3, 0, 2, 0]),
#  'fruit ambient': array([2, 3, 1, 3, 1]),
#  'gloves household': array([1, 3, 4, 4]),
#  'rice ambient': array([2, 3, 5]),
#  'tonic water': array([3, 4, 4]),
#  'cleansing body wash': array([1, 1, 0, 2, 1]),
#  'vegetables natural cucumber fresh fw': array([0, 2, 1, 2, 0]),
#  'vegetables natural broccoli cauliflower fresh fw': array([0, 2, 1, 2, 1]),
#  'nail polish & decoration': array([1, 3, 1, 0]),
#  'razor blades': array([1, 4, 2, 0]),
#  'dog chews bones treats & gift selections': array([1, 2, 2, 1]),
#  'pasta ambient': array([2, 3, 3, 1]),
#  'nasal decongestant': array([1, 0, 5, 1]),
#  'cream substitutes fresh': array([5, 2, 5, 0]),
#  'savoury pastry products fresh': array([5, 0, 2, 3]),
#  'cotton wool': array([1, 4, 5, 5]),
#  'nut butter ambient': array([2, 4, 1, 0]),
#  'cooking appliances & cooking ware': array([1, 2, 4, 1]),
#  'alcoholic pre mixed drinks': array([3, 1, 0, 0]),
#  'cakes gateaux fresh fw': array([5, 3, 3]),
#  'fruit banana fresh vw': array([0, 3, 1]),
#  'antacids': array([1, 0, 0, 0]),
#  'general analgesics': array([1, 0, 4, 0]),
#  'sport & leisure': array([1, 2, 1, 4]),
#  'home entertainment': array([1, 2, 4, 2]),
#  'shoe applications polish': array([1, 3, 1, 1]),
#  'air fresheners instant': array([1, 5, 3, 1, 0]),
#  'vegetables natural tomatoes fresh fw': array([0, 2, 1, 0, 1]),
#  'flavoured drinks non carbonated non cola': array([3, 4, 0, 2]),
#  'milk animal non flavoured ambient': array([2, 5, 0, 1]),
#  'cat food dry': array([5, 5, 2]),
#  'cream fresh': array([5, 0, 4, 1]),
#  'baking mix ambient': array([2, 0, 3, 0]),
#  'fish shellfish seafood natural frozen fw': array([4, 0, 3]),
#  'personal care combination & travel packs': array([1, 2, 3, 5]),
#  'vegetables natural carrot fresh fw': array([0, 2, 1, 0, 2]),
#  'rice frozen': array([4, 5, 5]),
#  'chocolate assorted inc multipack': array([5, 2, 2, 1]),
#  'facial tissues': array([1, 4, 3, 3]),
#  'protein based meat fish alternatives frzn': array([5, 4, 1, 1]),
#  'fruit apple pear family fresh fw': array([5, 3, 2]),
#  'specialist combination packs fresh': array([5, 2, 4]),
#  'sweet pastry dough frozen': array([4, 4, 1]),
#  'milk substitutes non flavoured fresh': array([5, 2, 0, 1]),
#  'tea': array([3, 5, 0, 1]),
#  'baby diapers': array([1, 1, 5, 3]),
#  'herbs spices': array([1, 5, 5, 0]),
#  'home appliances': array([1, 2, 4, 3]),
#  'candles non scented': array([1, 5, 5, 1]),
#  'ketchup ambient': array([2, 1, 3, 2]),
#  'cold flu remedies': array([1, 0, 3, 2]),
#  'sports energy sweets bars': array([3, 1, 3, 1]),
#  'digestive & liver & other intestinal remedies': array([1, 0, 2, 2]),
#  'blended fats spreads fresh': array([5, 2, 1, 1]),
#  'concentrates cordial squashes syrups': array([3, 1, 4, 0]),
#  'hair care': array([1, 4, 1, 4]),
#  'anti smoking products': array([1, 5, 2, 1]),
#  'snacks chips crisps tortilla': array([5, 1, 1, 3]),
#  'meat meat products fresh vw': array([0, 1, 0]),
#  'coffee rtd': array([3, 1, 1, 0]),
#  'brandy': array([3, 5, 1, 0]),
#  'vegetables natural peppers fresh vw': array([0, 0, 5]),
#  'pet litter & litter accessories': array([1, 2, 2, 4, 1]),
#  'butter fresh': array([5, 0, 4, 2]),
#  'vegetables natural onion fresh vw': array([0, 0, 0]),
#  'shaving cream foam gel oil': array([1, 4, 5, 2]),
#  'seeds ambient': array([2, 3, 1, 4]),
#  'sweet pastry dough ambient': array([2, 0, 3, 1]),
#  'confectionery spreads ambient': array([2, 2, 2, 3]),
#  'bags refuse': array([1, 5, 3, 3]),
#  'chutney pickle relish ambient': array([2, 1, 2]),
#  'cakes gateaux frozen': array([4, 1, 1, 0]),
#  'whisky': array([3, 5, 1, 1]),
#  'toothbrushes manual': array([1, 3, 0, 0, 0]),
#  'pasta fresh': array([5, 0, 1, 3]),
#  'fillings pastes spreads savoury fresh': array([5, 2, 5, 1]),
#  'fruit mixed fruit fresh fw': array([5, 3, 5, 1]),
#  'soup ambient': array([2, 3, 3, 2]),
#  'fish fingers frozen fw': array([4, 0, 4]),
#  'fruit frozen': array([4, 1, 5]),
#  'cider': array([3, 4, 5]),
#  'breadsticks crispbread cereal based cakes ambient': array([2, 0, 1, 1]),
#  'vegetables beans pods pulses exc rice ambient': array([0, 5, 3]),
#  'sugar candy gum': array([3, 0, 0, 1]),
#  'flavoured aperitifs mixers bitter fruits ginger ale': array([3, 1, 0, 1]),
#  'desserts frozen': array([4, 1, 1, 1]),
#  'travel motion sickness products': array([1, 0, 0, 1]),
#  'eye cosmetics': array([1, 4, 3, 5]),
#  'abrasive cleaning pads': array([1, 3, 4, 5]),
#  'noodles fresh': array([5, 0, 1, 4]),
#  'milk animal flavoured drinks': array([3, 3, 5]),
#  'cleaning scourers pads sponges': array([1, 1, 3, 1]),
#  'baby feeding accessories': array([1, 2, 0, 0]),
#  'sun protection': array([1, 4, 0, 0]),
#  'eye care': array([1, 4, 3, 1]),
#  'toothbrushes electric': array([1, 3, 0, 0, 1]),
#  'vegetables reconstituted prdcts frzn': array([0, 2, 4, 0]),
#  'personal care appliances': array([1, 2, 4, 4]),
#  'cosmetic removal': array([1, 4, 3, 4]),
#  'fruit varieties remaining fresh fw': array([5, 3, 1]),
#  'vegetables natural lettuce mixed leaves fresh fw': array([0, 2, 1, 1]),
#  'cough remedies': array([1, 0, 3, 3]),
#  'muscular pain relief': array([1, 0, 4, 1]),
#  'household disinfectants': array([1, 1, 0, 1, 1]),
#  'honey ambient': array([2, 3, 1, 5]),
#  'dental accessories': array([1, 3, 0, 4]),
#  'savoury biscuits crackers ambient': array([2, 0, 4, 1]),
#  'pet food': array([3, 3, 3, 1]),
#  'reptile food': array([5, 5, 3]),
#  'kitchen paper towel disposable': array([1, 1, 4, 1]),
#  'hair fixing temporary': array([1, 4, 1, 5]),
#  'candles scented': array([1, 5, 5, 2]),
#  'baby healthcare': array([1, 2, 5, 0]),
#  'baby formula': array([3, 0, 4]),
#  'fish shellfish seafood ambient': array([2, 5, 1]),
#  'vegetables reconstituted products fresh': array([0, 2, 4, 1]),
#  'vodka': array([3, 5, 1, 2]),
#  'bouillon stock ambient': array([2, 4, 2]),
#  'vegetables natural peppers fresh fw': array([0, 2, 1, 4]),
#  'fruit apple pear family fresh vw': array([0, 3, 2]),
#  'circulatory products': array([1, 5, 1, 0]),
#  'depilatories': array([1, 0, 0, 2]),
#  'small mammal food drinks': array([3, 3, 4]),
#  'kitchenware disposable': array([1, 1, 4, 2]),
#  'fabric softeners': array([1, 1, 0, 0, 2]),
#  'fruit orange fresh vw': array([0, 3, 3]),
#  'wine sparkling': array([3, 2, 2, 0]),
#  'soup stock bouillon fresh': array([4, 2, 0]),
#  'cooking edible oils ambient': array([2, 4, 5]),
#  'vegetables natural broccoli cauliflower fresh vw': array([0, 0, 2, 0]),
#  'jams marmalade ambient': array([2, 3, 1, 1]),
#  'dessert mix ambient': array([2, 2, 2, 1, 0]),
#  'smoking accessories': array([1, 5, 2, 2]),
#  'cosmetic combination packs & gift sets': array([1, 2, 3, 0, 0]),
#  'household stain removers': array([1, 1, 0, 5, 1]),
#  'vegetables salad vegetables fresh fw': array([0, 2, 5, 1]),
#  'household limescale mildew mould': array([1, 3, 5]),
#  'razors': array([1, 4, 2, 1]),
#  'head lice products treatments': array([1, 5, 0, 1]),
#  'cat milk drinks': array([3, 3, 1, 0]),
#  'prepared coatings decoration icings frostings ambient': array([2, 2, 0, 0]),
#  'flour ambient': array([2, 0, 3, 2]),
#  'first aid & medical surgical supplies': array([1, 2, 3, 3]),
#  'specialist combination packs ambient': array([2, 2, 4]),
#  'fish shellfish seafood fresh vw': array([0, 1, 1]),
#  'fruit citrus fresh fw': array([5, 3, 0, 1]),
#  'ingredients decorating ambient': array([2, 2, 2, 4]),
#  'salt': array([3, 5, 5]),
#  'snacks popcorn': array([3, 0, 2, 1]),
#  'gin': array([3, 5, 1, 3]),
#  'biscuits sweet fresh': array([5, 0, 0, 2]),
#  'pet hygiene & grooming': array([1, 2, 2, 5]),
#  'sugar substitutes ambient': array([2, 4, 0, 0]),
#  'yogurt yogurt substitute drinking': array([3, 1, 2, 0]),
#  'infusions fruit herbal': array([3, 1, 4, 1]),
#  'creamers ambient': array([2, 3, 2, 1]),
#  'vegetables natural potatoes fresh vw': array([0, 0, 4, 0]),
#  'auto dish salt': array([2, 1, 4]),
#  'sore throat remedies': array([1, 0, 3, 4]),
#  'diarrhoea products': array([1, 5, 4, 3]),
#  'combined meat fish seafood products fresh': array([5, 4, 4]),
#  'baby soothing hardware': array([1, 2, 0, 1]),
#  'polish furniture surface': array([1, 3, 1, 2]),
#  'cold sore treatments': array([1, 0, 1, 0]),
#  'fermented milk milk substitute drinking': array([3, 1, 2, 1]),
#  'nail care': array([1, 3, 1, 3]),
#  'protein based meat fish alternatives ambient': array([2, 5, 3]),
#  'fish food': array([5, 4, 2]),
#  'healthcare': array([1, 2, 5, 1]),
#  'aftershave': array([1, 4, 0, 1]),
#  'contact lens care': array([1, 3, 3, 0]),
#  'dog food drinks': array([3, 3, 0, 0]),
#  'dough fresh': array([5, 0, 2, 4]),
#  'dish pre wash treatment booster': array([1, 1, 2, 2]),
#  'potato meals frozen': array([4, 5, 2, 1]),
#  'margarine fresh': array([5, 0, 4, 3]),
#  'insect control': array([1, 5, 0, 2]),
#  'polenta ambient': array([2, 3, 4]),
#  'tooth stain removers': array([1, 3, 0, 1, 1]),
#  'self tan': array([1, 4, 0, 2]),
#  'cigars': array([3, 5, 2, 2]),
#  'beer lager ales low non alcoholic': array([3, 1, 5, 1]),
#  'vegetables salad vegetables fresh vw': array([0, 0, 1]),
#  'fillings pastes spreads savoury ambient': array([2, 2, 3, 0]),
#  'savoury pastry products frozen': array([4, 4, 2]),
#  'cheese ambient': array([2, 3, 2, 2]),
#  'stuffing bread based ambient': array([2, 0, 0, 1]),
#  'air treatments non electrical': array([1, 5, 3, 2]),
#  'denture brushes cleansers fixatives': array([1, 3, 0, 1, 2]),
#  'pasta frozen': array([4, 5, 1, 0]),
#  'vegetables potatoes ambient': array([0, 5, 4]),
#  'toilet cleaning system': array([1, 1, 3, 2]),
#  'photo': array([1, 4, 4, 2]),
#  'chocolate drinks': array([3, 0, 3, 1]),
#  'dessert sauces ambient': array([2, 1, 0, 1]),
#  'heat not burn cigarettes': array([1, 5, 2, 3]),
#  'pepper peppercorns': array([3, 0, 1]),
#  'bread frozen': array([4, 4, 3]),
#  'oral treatment': array([1, 0, 1, 1]),
#  'breakfast cereals toaster pastries ambient': array([2, 0, 1, 2]),
#  'foot heel toe caps cushions pads': array([1, 3, 2, 0]),
#  'mint sauce ambient': array([2, 1, 0, 2]),
#  'tobacco snuff': array([1, 5, 2, 4]),
#  'ear care': array([1, 3, 3, 1]),
#  'couscous ambient': array([2, 1, 5, 1]),
#  'cheese fresh vw': array([0, 1, 2]),
#  'antiseptic products': array([1, 1, 0, 1, 2]),
#  'liqueurs': array([3, 2, 5]),
#  'raising agents ambient': array([2, 2, 5]),
#  'tan accelerators': array([1, 4, 0, 3]),
#  'wine fortified styles': array([3, 2, 1]),
#  'intimate wash': array([1, 1, 1, 1]),
#  'rum': array([3, 5, 1, 4]),
#  'wine champagne': array([3, 2, 2, 1]),
#  'milk evaporated condensed ambient': array([2, 5, 4]),
#  'combined carbohydrate products ambient': array([2, 4, 0, 1]),
#  'vegetables with meat fish additives ambient': array([0, 4, 0]),
#  'potato meals ambient': array([2, 0, 5]),
#  'foot care hygiene': array([1, 3, 4, 1, 0]),
#  'raising agents fresh': array([5, 0, 5]),
#  'fruit citrus fresh vw': array([0, 3, 4]),
#  'intimate lubrication': array([1, 4, 5, 3]),
#  'pizza bases kits frozen': array([4, 3, 0]),
#  'pet deterrents attractants': array([1, 5, 0, 3]),
#  'breast feeding accessories': array([1, 2, 0, 2]),
#  'mustard ambient': array([2, 3, 1, 2]),
#  'joint products': array([1, 5, 1, 1]),
#  'pizza bases kits fresh': array([5, 0, 2, 5]),
#  'grooming bathing aids': array([1, 4, 5, 1, 3]),
#  'prepared bases unfilled ambient': array([2, 4, 4]),
#  'aftersun': array([1, 4, 0, 4]),
#  'beer & flavoured drink mixes': array([3, 1, 0, 2]),
#  'dental floss tape': array([1, 3, 0, 3]),
#  'shoe applications deodoriser disinfectant': array([1, 3, 4, 1, 1]),
#  'cocoa powder': array([3, 0, 5]),
#  'beer wine spirit making kits': array([3, 2, 3]),
#  'salads ready to eat ambient': array([2, 3, 0]),
#  'vegetables natural carrot fresh vw': array([0, 0, 2, 1]),
#  'homeopathic remedies treatments': array([1, 0, 2, 3]),
#  'shoe accessories': array([1, 2, 3, 2, 1]),
#  'ingredients ambient': array([2, 2, 2, 5]),
#  'auto dish rinse aid': array([1, 1, 2, 3]),
#  'herbs spices frozen': array([4, 5, 3]),
#  'cat food drinks': array([3, 3, 1, 1]),
#  'recipe mixes ambient': array([2, 2, 2, 1, 1]),
#  'spirits remaining': array([3, 5, 3]),
#  'potato gnocchi fresh': array([4, 5, 4]),
#  'noodles frozen': array([4, 5, 1, 1]),
#  'prepared coatings marzipan almond paste ambient': array([2, 2, 0, 1]),
#  'soda water': array([3, 4, 1]),
#  'coffee substitutes': array([3, 1, 1, 1]),
#  'laxatives': array([1, 0, 0, 3]),
#  'confectionery & gift confectionery & novelty': array([1, 2, 3, 0, 1]),
#  'wound dressing': array([1, 3, 4, 2, 1]),
#  'cosmetic accessories': array([1, 2, 3, 2, 2]),
#  'laundry colour care': array([1, 1, 1, 2]),
#  'milk substitutes flavoured drinks': array([3, 1, 2, 2]),
#  'cleaning system cloths dusters': array([1, 1, 3, 3]),
#  'body body & face cosmetics': array([1, 4, 3, 2, 1]),
#  'dough frozen': array([4, 4, 4]),
#  'stuffing bread based fresh': array([5, 0, 0, 3]),
#  'tartare sauce ambient': array([2, 1, 0, 3]),
#  'shoe applications cleaners': array([1, 3, 4, 1, 2]),
#  'marinades ambient': array([2, 1, 1, 1]),
#  'insect bite treatments': array([1, 3, 4, 0]),
#  'seafood cocktail sauce ambient': array([2, 1, 0, 4]),
#  'ice frozen': array([4, 1, 3]),
#  'baby care': array([1, 2, 5, 2]),
#  'foot insoles': array([1, 3, 2, 1]),
#  'fish shellfish seafood frozen fw': array([4, 0, 5]),
#  'fruit nuts fresh fw': array([5, 3, 4]),
#  'pipe openers treatments': array([1, 3, 4, 3]),
#  'eggs egg products ambient': array([2, 5, 2]),
#  'dips dressings sauces frozen': array([4, 1, 4]),
#  'genito urinary system & contraceptive products': array([1, 5, 4, 4]),
#  'auto dish washer fresheners': array([1, 1, 2, 4]),
#  'specialist combination packs frozen': array([4, 3, 1]),
#  'biscuits & confectionery & snacks assortments': array([5, 1, 5]),
#  'stimulants': array([3, 5, 4]),
#  'vegetables natural tomatoes fresh vw': array([0, 0, 4, 1]),
#  'cider low non alcoholic': array([3, 4, 2]),
#  'insect repellents personal': array([1, 5, 0, 4]),
#  'contraceptive products': array([1, 5, 4, 5]),
#  'air fresheners refrigerator': array([1, 5, 3, 5]),
#  'mouth care': array([1, 3, 0, 2, 0]),
#  'dog milk drinks': array([3, 3, 0, 1]),
#  'combined carbohydrate products fresh': array([5, 2, 1, 2]),
#  'marinades dry': array([5, 5, 4]),
#  'pizza bases kits ambient': array([2, 2, 2, 2]),
#  'soup stock bouillon frozen': array([4, 2, 1]),
#  'shaving depilation': array([1, 4, 2, 2]),
#  'malted drinks': array([3, 1, 0, 3]),
#  'vegetables with meat fish additives frzn': array([0, 4, 1]),
#  'butter marg edible fats ambient': array([2, 4, 1, 1]),
#  'pest control': array([1, 5, 0, 5]),
#  'cleaning system floor mops refills': array([1, 1, 3, 4]),
#  'spirits minor regional styles': array([3, 2, 4]),
#  'tea & infusions assortment': array([3, 1, 4, 2]),
#  'couscous fresh': array([5, 0, 1, 5]),
#  'vegetables natural lettuce mixed leaves fresh vw': array([0, 0, 3]),
#  'breath fresheners': array([1, 5, 3, 1, 1]),
#  'brain & nervous system': array([1, 4, 4, 3]),
#  'pain relief': array([1, 0, 4, 2]),
#  'oral hygiene': array([1, 3, 0, 2, 1]),
#  'air fresheners vacuum cleaners': array([1, 5, 3, 4]),
#  'stuffing bread based frozen': array([4, 4, 5]),
#  'cheese frozen': array([4, 1, 2]),
#  'polish metal': array([1, 3, 1, 4]),
#  'shoe applications waterproofing dubbin': array([1, 3, 4, 1, 3]),
#  'thickening agent ambient': array([2, 2, 3, 1]),
#  'cream substitutes ambient': array([2, 2, 3, 2]),
#  'anti snore treatments': array([1, 0, 5, 2]),
#  'breathing aids nasal strips': array([1, 5, 2, 5])}

# %%
lfs_dct = {}

for mod, did in mod_code.items():
    if str(did[:3]) not in lfs_dct:
        lfs_dct[str(did[:3])] = [mod]
    else:
        lfs_dct[str(did[:3])].append(mod)

# %%
lfs_dct
# Out:
# {'[1 1 0]': ['bleach ammonia',
#   'bath additives',
#   'toilet cleaners fresheners',
#   'carpet fresheners',
#   'cleansing soap',
#   'laundry detergents',
#   'textile fresheners',
#   'household cleaners',
#   'hand sanitizers',
#   'cleansing body wash',
#   'household disinfectants',
#   'fabric softeners',
#   'household stain removers',
#   'antiseptic products'],
#  '[0 5 0]': ['garden & flora'],
#  '[1 2 1]': ['stationery & printed material & services',
#   'home furnishings & decor',
#   'kitchen & tableware',
#   'home do it yourself',
#   'sport & leisure'],
#  '[1 2 3]': ['homecare merchandise',
#   'clothing & personal accessories',
#   'toys',
#   'personal care combination & travel packs',
#   'cosmetic combination packs & gift sets',
#   'first aid & medical surgical supplies',
#   'shoe accessories',
#   'confectionery & gift confectionery & novelty',
#   'cosmetic accessories'],
#  '[1 4 5]': ['skin conditioning moisturising',
#   'skin cleansing & toning',
#   'skin treatments dermatologicals',
#   'fragrances cologne',
#   'massage products',
#   'cotton wool',
#   'shaving cream foam gel oil',
#   'intimate lubrication',
#   'grooming bathing aids'],
#  '[3 2 0]': ['wine still light table styles'],
#  '[3 0 0]': ['sugar candy', 'sugar candy gum'],
#  '[5 1 1]': ['snacks chips crisps reconstituted extruded',
#   'snacks chips crisps',
#   'snacks pretzels',
#   'snacks chips crisps tortilla'],
#  '[5 4 0]': ['meat products fresh'],
#  '[5 5 0]': ['dog food dry'],
#  '[5 4 3]': ['meat cuts joints whole fresh fw'],
#  '[5 0 2]': ['eggs egg products fresh',
#   'sweet pastry dough fresh',
#   'dough products fresh',
#   'savoury pastry products fresh',
#   'dough fresh',
#   'pizza bases kits fresh'],
#  '[5 2 2]': ['chocolate single variety', 'chocolate assorted inc multipack'],
#  '[1 0 3]': ['cough cold & other respiratory remedies & accessories',
#   'allergy hayfever remedies',
#   'cold flu remedies',
#   'cough remedies',
#   'sore throat remedies'],
#  '[5 3 0]': ['fruit orange fresh fw', 'fruit citrus fresh fw'],
#  '[5 0 0]': ['cheese fresh fw',
#   'bread fresh fw',
#   'biscuits sweet fresh',
#   'stuffing bread based fresh'],
#  '[0 5 1]': ['vegetables salad vegetables remaining varieties ambient'],
#  '[2 5 0]': ['milk substitutes non flavoured ambient',
#   'milk animal non flavoured ambient'],
#  '[2 0 4]': ['biscuits sweet ambient', 'savoury biscuits crackers ambient'],
#  '[3 4 0]': ['flavoured drinks carbonated non cola',
#   'flavoured drinks carbonated cola',
#   'flavoured drinks non carbonated non cola'],
#  '[5 5 1]': ['cat food wet'],
#  '[2 1 3]': ['vinegar ambient', 'mayonnaise ambient', 'ketchup ambient'],
#  '[4 1 0]': ['ice cream novelties sorbet yogurt frozen'],
#  '[5 2 3]': ['yogurt spoonable fresh'],
#  '[1 4 1]': ['hair conditioners',
#   'hair shampoo',
#   'hair styling',
#   'hair colourants',
#   'hair care',
#   'hair fixing temporary'],
#  '[1 1 5]': ['toilet tissue',
#   'sanitary protection',
#   'incontinence',
#   'baby diapers'],
#  '[5 1 2]': ['baby food'],
#  '[1 3 0]': ['tooth cleaning',
#   'mouthwash oral rinses oral rinse antiseptics',
#   'toothbrushes manual',
#   'toothbrushes electric',
#   'dental accessories',
#   'tooth stain removers',
#   'denture brushes cleansers fixatives',
#   'dental floss tape',
#   'mouth care',
#   'oral hygiene'],
#  '[1 2 2]': ['pets & pet care',
#   'pet general accessories',
#   'cat food treats & gift selections',
#   'pet fish treatments aquariums accessories',
#   'dog chews bones treats & gift selections',
#   'pet litter & litter accessories',
#   'pet hygiene & grooming'],
#  '[3 3 2]': ['bird food drinks'],
#  '[2 0 0]': ['bread ambient', 'stuffing bread based ambient'],
#  '[1 1 2]': ['auto dish detergent',
#   'hand dish detergent',
#   'dish pre wash treatment booster',
#   'auto dish rinse aid',
#   'auto dish washer fresheners'],
#  '[2 3 1]': ['nuts ambient',
#   'sugar ambient',
#   'fruit ambient',
#   'seeds ambient',
#   'honey ambient',
#   'jams marmalade ambient',
#   'mustard ambient'],
#  '[1 5 2]': ['electronic cigarettes cigars pipes vaporizers',
#   'anti smoking products',
#   'smoking accessories',
#   'heat not burn cigarettes',
#   'tobacco snuff',
#   'breathing aids nasal strips'],
#  '[1 2 4]': ['computing & telecommunications',
#   'cooking appliances & cooking ware',
#   'home entertainment',
#   'home appliances',
#   'personal care appliances'],
#  '[0 2 2]': ['vegetables natural remaining varieties fresh'],
#  '[5 3 5]': ['fruit berries fresh fw', 'fruit mixed fruit fresh fw'],
#  '[1 5 4]': ['slimming aids',
#   'weight gain products',
#   'deodorants',
#   'diarrhoea products',
#   'genito urinary system & contraceptive products',
#   'contraceptive products'],
#  '[5 0 3]': ['cooking sauce fresh', 'dips dressings sauces fresh'],
#  '[3 3 3]': ['dog food wet', 'pet food'],
#  '[3 1 3]': ['sports energy drinks', 'sports energy sweets bars'],
#  '[1 0 5]': ['calming & sleeping',
#   'nasal decongestant',
#   'anti snore treatments'],
#  '[4 0 0]': ['fish shellfish seafood prepared frozen fw'],
#  '[3 1 5]': ['beer lager ales', 'beer lager ales low non alcoholic'],
#  '[5 1 0]': ['cereal fruit muesli bars'],
#  '[5 4 5]': ['fish shellfish seafood fresh fw'],
#  '[3 5 2]': ['juices', 'cigarettes', 'cigars'],
#  '[5 2 0]': ['milk animal non flavoured fresh',
#   'milk substitutes non flavoured fresh'],
#  '[1 5 0]': ['pet flea tick worming products',
#   'head lice products treatments',
#   'insect control',
#   'pet deterrents attractants',
#   'insect repellents personal',
#   'pest control'],
#  '[2 1 0]': ['hot cooking sauce ambient',
#   'dessert sauces ambient',
#   'mint sauce ambient',
#   'tartare sauce ambient',
#   'seafood cocktail sauce ambient'],
#  '[3 5 0]': ['coffee', 'tea'],
#  '[5 1 3]': ['bread sandwiches filled rolls wraps'],
#  '[2 0 1]': ['breakfast cereals ambient',
#   'breadsticks crispbread cereal based cakes ambient',
#   'breakfast cereals toaster pastries ambient'],
#  '[0 2 0]': ['herbs spices fresh fw'],
#  '[4 0 1]': ['meat cuts joints whole frozen fw'],
#  '[3 4 3]': ['mineral water non carbonated', 'mineral water carbonated'],
#  '[2 3 3]': ['noodles ambient', 'pasta ambient', 'soup ambient'],
#  '[4 5 0]': ['pizza frozen'],
#  '[2 4 3]': ['fruit & nut combination dried ambient'],
#  '[1 1 1]': ['laundry special care', 'intimate wash', 'laundry colour care'],
#  '[2 2 1]': ['potato products ambient'],
#  '[1 4 3]': ['lip cosmetics',
#   'face cosmetics',
#   'facial tissues',
#   'eye cosmetics',
#   'eye care',
#   'cosmetic removal',
#   'body body & face cosmetics'],
#  '[0 2 1]': ['vegetables natural potatoes fresh fw',
#   'vegetables natural onion fresh fw',
#   'vegetables natural mushroom fresh fw',
#   'vegetables natural cucumber fresh fw',
#   'vegetables natural broccoli cauliflower fresh fw',
#   'vegetables natural tomatoes fresh fw',
#   'vegetables natural carrot fresh fw',
#   'vegetables natural lettuce mixed leaves fresh fw',
#   'vegetables natural peppers fresh fw'],
#  '[4 0 2]': ['meat products frozen'],
#  '[1 3 4]': ['plasters',
#   'gloves household',
#   'abrasive cleaning pads',
#   'foot care hygiene',
#   'shoe applications deodoriser disinfectant',
#   'wound dressing',
#   'shoe applications cleaners',
#   'insect bite treatments',
#   'pipe openers treatments',
#   'shoe applications waterproofing dubbin'],
#  '[4 5 2]': ['potato products frozen', 'potato meals frozen'],
#  '[5 0 1]': ['potato meals fresh',
#   'rice fresh',
#   'pizza fresh',
#   'pasta fresh',
#   'noodles fresh',
#   'couscous fresh'],
#  '[1 0 2]': ['vitamins & minerals & nutritional & health supplements',
#   'herbal botanical remedies & treatments & supplements',
#   'digestive & liver & other intestinal remedies',
#   'homeopathic remedies treatments'],
#  '[2 2 2]': ['meal kits ambient',
#   'confectionery spreads ambient',
#   'dessert mix ambient',
#   'ingredients decorating ambient',
#   'ingredients ambient',
#   'recipe mixes ambient',
#   'pizza bases kits ambient'],
#  '[3 0 3]': ['chocolate novelties', 'chocolate drinks'],
#  '[5 0 4]': ['desserts fresh',
#   'cream fresh',
#   'butter fresh',
#   'margarine fresh'],
#  '[2 0 2]': ['cakes gateaux ambient'],
#  '[2 3 2]': ['desserts ambient', 'creamers ambient', 'cheese ambient'],
#  '[1 5 3]': ['air fresheners continuous',
#   'air fresheners instant',
#   'bags refuse',
#   'air treatments non electrical',
#   'air fresheners refrigerator',
#   'breath fresheners',
#   'air fresheners vacuum cleaners'],
#  '[2 1 1]': ['dips dressings sauces ambient', 'marinades ambient'],
#  '[1 1 3]': ['cleaning cloths',
#   'cleaning scourers pads sponges',
#   'toilet cleaning system',
#   'cleaning system cloths dusters',
#   'cleaning system floor mops refills'],
#  '[0 2 3]': ['vegetables salad vegetables frozen'],
#  '[0 3 0]': ['fruit varieties remaining fresh vw'],
#  '[5 4 1]': ['protein based meat fish alternatives fresh',
#   'protein based meat fish alternatives frzn'],
#  '[1 1 4]': ['tableware drinkware disposable',
#   'kitchen paper towel disposable',
#   'kitchenware disposable'],
#  '[5 2 1]': ['butter marg edible fats fresh',
#   'blended fats spreads fresh',
#   'combined carbohydrate products fresh'],
#  '[4 4 0]': ['dough products frozen'],
#  '[2 1 5]': ['syrup treacle molasses ambient', 'couscous ambient'],
#  '[5 1 4]': ['snacks dipping fresh'],
#  '[0 2 5]': ['salads fresh fw', 'vegetables salad vegetables fresh fw'],
#  '[2 5 5]': ['meat products ambient'],
#  '[1 4 4]': ['automotive', 'optical', 'photo', 'brain & nervous system'],
#  '[0 5 2]': ['vegetables tomatoes ambient'],
#  '[3 0 2]': ['snacks', 'snacks popcorn'],
#  '[2 3 5]': ['rice ambient'],
#  '[3 4 4]': ['tonic water'],
#  '[1 3 1]': ['nail polish & decoration',
#   'shoe applications polish',
#   'polish furniture surface',
#   'nail care',
#   'polish metal'],
#  '[1 4 2]': ['razor blades', 'razors', 'shaving depilation'],
#  '[5 2 5]': ['cream substitutes fresh',
#   'fillings pastes spreads savoury fresh'],
#  '[2 4 1]': ['nut butter ambient', 'butter marg edible fats ambient'],
#  '[3 1 0]': ['alcoholic pre mixed drinks',
#   'flavoured aperitifs mixers bitter fruits ginger ale',
#   'beer & flavoured drink mixes',
#   'malted drinks'],
#  '[5 3 3]': ['cakes gateaux fresh fw'],
#  '[0 3 1]': ['fruit banana fresh vw'],
#  '[1 0 0]': ['antacids',
#   'travel motion sickness products',
#   'depilatories',
#   'laxatives'],
#  '[1 0 4]': ['general analgesics', 'muscular pain relief', 'pain relief'],
#  '[5 5 2]': ['cat food dry'],
#  '[2 0 3]': ['baking mix ambient',
#   'sweet pastry dough ambient',
#   'flour ambient'],
#  '[4 0 3]': ['fish shellfish seafood natural frozen fw'],
#  '[4 5 5]': ['rice frozen'],
#  '[5 3 2]': ['fruit apple pear family fresh fw'],
#  '[5 2 4]': ['specialist combination packs fresh'],
#  '[4 4 1]': ['sweet pastry dough frozen'],
#  '[1 5 5]': ['herbs spices', 'candles non scented', 'candles scented'],
#  '[3 1 4]': ['concentrates cordial squashes syrups',
#   'infusions fruit herbal',
#   'tea & infusions assortment'],
#  '[0 1 0]': ['meat meat products fresh vw'],
#  '[3 1 1]': ['coffee rtd', 'coffee substitutes'],
#  '[3 5 1]': ['brandy', 'whisky', 'vodka', 'gin', 'rum'],
#  '[0 0 5]': ['vegetables natural peppers fresh vw'],
#  '[0 0 0]': ['vegetables natural onion fresh vw'],
#  '[2 1 2]': ['chutney pickle relish ambient'],
#  '[4 1 1]': ['cakes gateaux frozen', 'desserts frozen'],
#  '[4 0 4]': ['fish fingers frozen fw'],
#  '[4 1 5]': ['fruit frozen'],
#  '[3 4 5]': ['cider'],
#  '[0 5 3]': ['vegetables beans pods pulses exc rice ambient'],
#  '[3 3 5]': ['milk animal flavoured drinks'],
#  '[1 2 0]': ['baby feeding accessories',
#   'baby soothing hardware',
#   'breast feeding accessories'],
#  '[1 4 0]': ['sun protection',
#   'aftershave',
#   'self tan',
#   'tan accelerators',
#   'aftersun'],
#  '[0 2 4]': ['vegetables reconstituted prdcts frzn',
#   'vegetables reconstituted products fresh'],
#  '[5 3 1]': ['fruit varieties remaining fresh fw'],
#  '[5 5 3]': ['reptile food'],
#  '[1 2 5]': ['baby healthcare', 'healthcare', 'baby care'],
#  '[3 0 4]': ['baby formula'],
#  '[2 5 1]': ['fish shellfish seafood ambient'],
#  '[2 4 2]': ['bouillon stock ambient'],
#  '[0 3 2]': ['fruit apple pear family fresh vw'],
#  '[1 5 1]': ['circulatory products', 'joint products'],
#  '[3 3 4]': ['small mammal food drinks'],
#  '[0 3 3]': ['fruit orange fresh vw'],
#  '[3 2 2]': ['wine sparkling', 'wine champagne'],
#  '[4 2 0]': ['soup stock bouillon fresh'],
#  '[2 4 5]': ['cooking edible oils ambient'],
#  '[0 0 2]': ['vegetables natural broccoli cauliflower fresh vw',
#   'vegetables natural carrot fresh vw'],
#  '[1 3 5]': ['household limescale mildew mould'],
#  '[3 3 1]': ['cat milk drinks', 'cat food drinks'],
#  '[2 2 0]': ['prepared coatings decoration icings frostings ambient',
#   'prepared coatings marzipan almond paste ambient'],
#  '[2 2 4]': ['specialist combination packs ambient'],
#  '[0 1 1]': ['fish shellfish seafood fresh vw'],
#  '[3 5 5]': ['salt'],
#  '[2 4 0]': ['sugar substitutes ambient',
#   'combined carbohydrate products ambient'],
#  '[3 1 2]': ['yogurt yogurt substitute drinking',
#   'fermented milk milk substitute drinking',
#   'milk substitutes flavoured drinks'],
#  '[0 0 4]': ['vegetables natural potatoes fresh vw',
#   'vegetables natural tomatoes fresh vw'],
#  '[2 1 4]': ['auto dish salt'],
#  '[5 4 4]': ['combined meat fish seafood products fresh'],
#  '[1 0 1]': ['cold sore treatments', 'oral treatment'],
#  '[2 5 3]': ['protein based meat fish alternatives ambient'],
#  '[5 4 2]': ['fish food'],
#  '[1 3 3]': ['contact lens care', 'ear care'],
#  '[3 3 0]': ['dog food drinks', 'dog milk drinks'],
#  '[2 3 4]': ['polenta ambient'],
#  '[0 0 1]': ['vegetables salad vegetables fresh vw'],
#  '[2 2 3]': ['fillings pastes spreads savoury ambient',
#   'thickening agent ambient',
#   'cream substitutes ambient'],
#  '[4 4 2]': ['savoury pastry products frozen'],
#  '[4 5 1]': ['pasta frozen', 'noodles frozen'],
#  '[0 5 4]': ['vegetables potatoes ambient'],
#  '[3 0 1]': ['pepper peppercorns'],
#  '[4 4 3]': ['bread frozen'],
#  '[1 3 2]': ['foot heel toe caps cushions pads', 'foot insoles'],
#  '[0 1 2]': ['cheese fresh vw'],
#  '[3 2 5]': ['liqueurs'],
#  '[2 2 5]': ['raising agents ambient'],
#  '[3 2 1]': ['wine fortified styles'],
#  '[2 5 4]': ['milk evaporated condensed ambient'],
#  '[0 4 0]': ['vegetables with meat fish additives ambient'],
#  '[2 0 5]': ['potato meals ambient'],
#  '[5 0 5]': ['raising agents fresh'],
#  '[0 3 4]': ['fruit citrus fresh vw'],
#  '[4 3 0]': ['pizza bases kits frozen'],
#  '[2 4 4]': ['prepared bases unfilled ambient'],
#  '[3 0 5]': ['cocoa powder'],
#  '[3 2 3]': ['beer wine spirit making kits'],
#  '[2 3 0]': ['salads ready to eat ambient'],
#  '[4 5 3]': ['herbs spices frozen'],
#  '[3 5 3]': ['spirits remaining'],
#  '[4 5 4]': ['potato gnocchi fresh'],
#  '[3 4 1]': ['soda water'],
#  '[4 4 4]': ['dough frozen'],
#  '[4 1 3]': ['ice frozen'],
#  '[4 0 5]': ['fish shellfish seafood frozen fw'],
#  '[5 3 4]': ['fruit nuts fresh fw'],
#  '[2 5 2]': ['eggs egg products ambient'],
#  '[4 1 4]': ['dips dressings sauces frozen'],
#  '[4 3 1]': ['specialist combination packs frozen'],
#  '[5 1 5]': ['biscuits & confectionery & snacks assortments'],
#  '[3 5 4]': ['stimulants'],
#  '[3 4 2]': ['cider low non alcoholic'],
#  '[5 5 4]': ['marinades dry'],
#  '[4 2 1]': ['soup stock bouillon frozen'],
#  '[0 4 1]': ['vegetables with meat fish additives frzn'],
#  '[3 2 4]': ['spirits minor regional styles'],
#  '[0 0 3]': ['vegetables natural lettuce mixed leaves fresh vw'],
#  '[4 4 5]': ['stuffing bread based frozen'],
#  '[4 1 2]': ['cheese frozen']}

# %%
with open("mod_code.pkl", "wb") as f:
    pickle.dump(mod_code, f)

# %%
import pickle
with open("mod_code.pkl", "rb") as f:
    mod_code = pickle.load(f)

# %%
dv = list(mod_code.values())

lns = []

for d in dv:
    lns.append(len(d))

# %%
max(lns), min(lns), sum(lns) / len(lns)
# Out:
# (5, 3, 3.8730512249443207)

# %%
# CUDA_VISIBLE_DEVICES=4,3 accelerate launch --num_processes=2 train_final.py --train_data train.csv --val_data val.csv --model_name "t5-small" --bs 64 --eval_every 1000 --pred_type br --num_epochs 16
